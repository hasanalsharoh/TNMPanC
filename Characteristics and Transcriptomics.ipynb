# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from scipy.stats import ttest_ind
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
import gseapy as gp
from gseapy import barplot, dotplot
from gseapy.plot import gseaplot
from sanbomics.plots import volcano
from sanbomics.tools import id_map
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score, roc_curve, auc, precision_recall_curve
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost.sklearn import XGBClassifier
import xgboost as xgb
from skopt import BayesSearchCV
import lifelines
from lifelines import KaplanMeierFitter, CoxPHFitter
import scanpy as sc

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# # Survival analysis

# %%
sur= pd.read_csv(r" Kaplan Meier.txt", sep='\t') # Replace with path for Kaplan Meier.txt, keep r"" 
tmakmf=sur[sur['Group']=='TMA']
twakmf=sur[sur['Group']=='TWA']
malkmf=sur[sur['gender']=='male']
femkmf=sur[sur['gender']=='female']
kmftma=KaplanMeierFitter()
kmftwa=KaplanMeierFitter()
kmfmal=KaplanMeierFitter()
kmffem=KaplanMeierFitter()
kmf=KaplanMeierFitter()
kmftma.fit(tmakmf['days_to_death'],event_observed=(tmakmf['vital_status']=='Dead'), label='Tumors with nodal extensions')
kmftwa.fit(twakmf['days_to_death'],event_observed=(twakmf['vital_status']=='Dead'), label='Tumors without nodal extensions')
kmfmal.fit(malkmf['days_to_death'],event_observed=(malkmf['vital_status']=='Dead'), label='Males')
kmffem.fit(femkmf['days_to_death'],event_observed=(femkmf['vital_status']=='Dead'), label='Females')
kmf.fit(sur['days_to_death'],event_observed=(sur['vital_status']=='Dead'))
# Out:
# <lifelines.KaplanMeierFitter:"KM_estimate", fitted with 227 total observations, 74 right-censored observations>

# %%
kmf.median_survival_time_
# Out:
# 732.0

# %%
kmftma.median_survival_time_
# Out:
# 691.0

# %%
kmftwa.median_survival_time_
# Out:
# 1213.0

# %%
kmfmal.median_survival_time_
# Out:
# 723.0

# %%
kmffem.median_survival_time_
# Out:
# 743.0

# %%
plt.figure(figsize=(8, 6))
kmftma.plot(ci_show= False, show_censors=True, censor_styles={"marker": "+"})
kmftwa.plot(ci_show= False, show_censors=True, censor_styles={"marker": "+"})
plt.title('Kaplan-Meier Survival Curves for pancreatic tumor groups')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.show()

# %%
plt.figure(figsize=(8, 6))
kmfmal.plot(ci_show= False, show_censors=True, censor_styles={"marker": "+"})
kmffem.plot(ci_show= False, show_censors=True, censor_styles={"marker": "+"})

plt.title('Kaplan-Meier Survival Curves for gender')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.show()

# %%
cphdf = sur.drop(['case_submitter_id','gender','age_at_index'],axis=1)

# %%
cphdf['Group']=cphdf['Group'].map({'TMA':1, 'TWA':0})
cphdf['vital_status']= cphdf['vital_status'].map({'Alive':0,'Dead':1})

# %%
cphdf['vital_status'].fillna(2, inplace=True)

# %%
cph = CoxPHFitter()
cph.fit(cphdf, duration_col='days_to_death', event_col='vital_status' )
# Out:
# <lifelines.CoxPHFitter: fitted with 227 total observations, 68 right-censored observations>

# %%
cph.hazard_ratios_
# Out:
# covariate
# Group    1.370998
# Name: exp(coef), dtype: float64

# %%
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 227 total observations, 68 right-censored observations>
#              duration col = 'days_to_death'
#                 event col = 'vital_status'
#       baseline estimation = breslow
#    number of observations = 227
# number of events observed = 159
#    partial log-likelihood = -784.95
#          time fit was run = 2023-12-22 16:27:30 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# Group       0.32       1.37       0.21            -0.10             0.73                 0.91                 2.07
#
#             cmp to    z    p   -log2(p)
# covariate
# Group         0.00 1.49 0.14       2.88
# ---
# Concordance = 0.53
# Partial AIC = 1571.89
# log-likelihood ratio test = 2.38 on 1 df
# -log2(p) of ll-ratio test = 3.03

# %%
from lifelines.statistics import logrank_test

# Assuming you have already fitted Kaplan-Meier curves for TMA and TWA (kmf_tma, kmf_twa)
results = logrank_test(tmakmf['days_to_death'], twakmf['days_to_death'], tmakmf['vital_status'] == 'Dead', twakmf['vital_status'] == 'Dead')

print(results.p_value)
# Out:
# 0.15001424122561555

# %% [markdown]
# # Primary Characteristics of Study Population

# %%
chars= r" \Characteristics for Descriptive Statistics of Population.txt" # Replace with path for Characteristics for Descriptive Statistics of Population.txt
dfchars= pd.read_csv(chars, sep='\t')

# %%
dfchars['age_in_years']=dfchars['age_at_diagnosis_days']/365.25

# %%
dfchars.describe()
# Out:
#        days_to_death  age_at_diagnosis_days  age_in_years
# count     208.000000             208.000000    208.000000
# mean     3734.197115           23729.817308     64.968699
# std      4485.176094            3854.696179     10.553583
# min         1.000000           11659.000000     31.920602
# 25%       372.500000           21880.750000     59.906229
# 50%       748.500000           23881.500000     65.383984
# 75%      9999.000000           26699.000000     73.097878
# max      9999.000000           31393.000000     85.949350

# %%
categorical_columns = ['vital_status', 'Group', 'gender', 'ajcc_pathologic_m', 'ajcc_pathologic_n', 'ajcc_pathologic_t', 'primary_diagnosis', 'site_of_resection_or_biopsy','ajcc_pathologic_stage']
categorical_summary = {col: dfchars[col].value_counts(normalize=True) for col in categorical_columns}

# %%
# Create an empty dictionary to store summaries
summary_dict = {}

# Iterate through each categorical column
for column in categorical_columns:
    # Calculate value counts
    value_counts = dfchars[column].value_counts()
    
    # Calculate percentages
    percentages = dfchars[column].value_counts(normalize=True) * 100
    
    # Create a summary DataFrame
    summary_df = pd.DataFrame({
        'Count': value_counts,
        'Percentage': percentages
    })
    
    # Store the summary DataFrame in the dictionary
    summary_dict[column] = summary_df

# Print summaries for each categorical column
for column, summary_df in summary_dict.items():
    print(f"Summary for '{column}':\n{summary_df}\n")
# Out:
# Summary for 'vital_status':
#          Count  Percentage
# Dead       140   67.307692
# Alive       62   29.807692
# Unknown      6    2.884615
#
# Summary for 'Group':
#      Count  Percentage
# TMA    168   80.769231
# TWA     40   19.230769
#
# Summary for 'gender':
#         Count  Percentage
# male      104        50.0
# female    104        50.0
#
# Summary for 'ajcc_pathologic_m':
#          Count  Percentage
# M0         191   91.826923
# M1          14    6.730769
# Unknown      2    0.961538
# M1b          1    0.480769
#
# Summary for 'ajcc_pathologic_n':
#          Count  Percentage
# N1         123   59.134615
# N0          43   20.673077
# N2          39   18.750000
# Unknown      2    0.961538
# N1b          1    0.480769
#
# Summary for 'ajcc_pathologic_t':
#          Count  Percentage
# T3         138   66.346154
# T2          57   27.403846
# T4           4    1.923077
# T1c          4    1.923077
# Unknown      3    1.442308
# T1           2    0.961538
#
# Summary for 'primary_diagnosis':
#                                                     Count  Percentage
# Infiltrating duct carcinoma, NOS                      195   93.750000
# Adenocarcinoma, NOS                                    10    4.807692
# Mucinous adenocarcinoma                                 2    0.961538
# Intraductal papillary-mucinous carcinoma, invasive      1    0.480769
#
# Summary for 'site_of_resection_or_biopsy':
#                                 Count  Percentage
# Head of pancreas                  158   75.961538
# Pancreas, NOS                      19    9.134615
# Body of pancreas                   17    8.173077
# Tail of pancreas                   11    5.288462
# Overlapping lesion of pancreas      2    0.961538
# Pancreatic neck                     1    0.480769
#
# Summary for 'ajcc_pathologic_stage':
#            Count  Percentage
# Stage IIB    102   49.038462
# Stage III     49   23.557692
# Stage IIA     22   10.576923
# Stage IB      17    8.173077
# Stage IV      14    6.730769
# Unknown        2    0.961538
# Stage I        1    0.480769
# Stage IA       1    0.480769

# %%
tmchars= dfchars[dfchars['Group']== 'TMA']

# %%
tmchars.describe()
# Out:
#        days_to_death  age_at_diagnosis_days  age_in_years
# count     168.000000             168.000000    168.000000
# mean     3533.809524           23405.196429     64.079935
# std      4415.540501            3976.482737     10.887016
# min         1.000000           11659.000000     31.920602
# 25%       372.500000           21480.250000     58.809719
# 50%       708.000000           23606.000000     64.629706
# 75%      9999.000000           26293.500000     71.987680
# max      9999.000000           31393.000000     85.949350

# %%
# Create an empty dictionary to store summaries
summary_tmdict = {}

# Iterate through each categorical column
for column in categorical_columns:
    # Calculate value counts
    value_counts = tmchars[column].value_counts()
    
    # Calculate percentages
    percentages = tmchars[column].value_counts(normalize=True) * 100
    
    # Create a summary DataFrame
    summary_tmdf = pd.DataFrame({
        'Count': value_counts,
        'Percentage': percentages
    })
    
    # Store the summary DataFrame in the dictionary
    summary_tmdict[column] = summary_tmdf

# Print summaries for each categorical column
for column, summary_tmdf in summary_tmdict.items():
    print(f"Summary for '{column}':\n{summary_tmdf}\n")
# Out:
# Summary for 'vital_status':
#          Count  Percentage
# Dead       117   69.642857
# Alive       46   27.380952
# Unknown      5    2.976190
#
# Summary for 'Group':
#      Count  Percentage
# TMA    168       100.0
#
# Summary for 'gender':
#         Count  Percentage
# female     88   52.380952
# male       80   47.619048
#
# Summary for 'ajcc_pathologic_m':
#          Count  Percentage
# M0         151   89.880952
# M1          14    8.333333
# Unknown      2    1.190476
# M1b          1    0.595238
#
# Summary for 'ajcc_pathologic_n':
#          Count  Percentage
# N1         123   73.214286
# N2          39   23.214286
# N0           3    1.785714
# Unknown      2    1.190476
# N1b          1    0.595238
#
# Summary for 'ajcc_pathologic_t':
#          Count  Percentage
# T3         115   68.452381
# T2          41   24.404762
# T4           4    2.380952
# T1c          4    2.380952
# Unknown      3    1.785714
# T1           1    0.595238
#
# Summary for 'primary_diagnosis':
#                                                     Count  Percentage
# Infiltrating duct carcinoma, NOS                      159   94.642857
# Adenocarcinoma, NOS                                     6    3.571429
# Mucinous adenocarcinoma                                 2    1.190476
# Intraductal papillary-mucinous carcinoma, invasive      1    0.595238
#
# Summary for 'site_of_resection_or_biopsy':
#                                 Count  Percentage
# Head of pancreas                  134   79.761905
# Body of pancreas                   12    7.142857
# Pancreas, NOS                      12    7.142857
# Tail of pancreas                    8    4.761905
# Pancreatic neck                     1    0.595238
# Overlapping lesion of pancreas      1    0.595238
#
# Summary for 'ajcc_pathologic_stage':
#            Count  Percentage
# Stage IIB    101   60.119048
# Stage III     49   29.166667
# Stage IV      14    8.333333
# Stage IB       2    1.190476
# Unknown        2    1.190476

# %%
twchars= dfchars[dfchars['Group']=='TWA']

# %%
twchars.describe()
# Out:
#        days_to_death  age_at_diagnosis_days  age_in_years
# count      40.000000              40.000000     40.000000
# mean     4575.825000           25093.225000     68.701506
# std      4731.510107            2965.680451      8.119591
# min       117.000000           17628.000000     48.262834
# 25%       371.750000           23590.500000     64.587269
# 50%      1107.500000           25269.500000     69.184120
# 75%      9999.000000           27180.000000     74.414784
# max      9999.000000           31222.000000     85.481177

# %%
# Create an empty dictionary to store summaries
summary_twdict = {}

# Iterate through each categorical column
for column in categorical_columns:
    # Calculate value counts
    value_counts = twchars[column].value_counts()
    
    # Calculate percentages
    percentages = twchars[column].value_counts(normalize=True) * 100
    
    # Create a summary DataFrame
    summary_twdf = pd.DataFrame({
        'Count': value_counts,
        'Percentage': percentages
    })
    
    # Store the summary DataFrame in the dictionary
    summary_twdict[column] = summary_twdf

# Print summaries for each categorical column
for column, summary_twdf in summary_twdict.items():
    print(f"Summary for '{column}':\n{summary_twdf}\n")
# Out:
# Summary for 'vital_status':
#          Count  Percentage
# Dead        23        57.5
# Alive       16        40.0
# Unknown      1         2.5
#
# Summary for 'Group':
#      Count  Percentage
# TWA     40       100.0
#
# Summary for 'gender':
#         Count  Percentage
# male       24        60.0
# female     16        40.0
#
# Summary for 'ajcc_pathologic_m':
#     Count  Percentage
# M0     40       100.0
#
# Summary for 'ajcc_pathologic_n':
#     Count  Percentage
# N0     40       100.0
#
# Summary for 'ajcc_pathologic_t':
#     Count  Percentage
# T3     23        57.5
# T2     16        40.0
# T1      1         2.5
#
# Summary for 'primary_diagnosis':
#                                   Count  Percentage
# Infiltrating duct carcinoma, NOS     36        90.0
# Adenocarcinoma, NOS                   4        10.0
#
# Summary for 'site_of_resection_or_biopsy':
#                                 Count  Percentage
# Head of pancreas                   24        60.0
# Pancreas, NOS                       7        17.5
# Body of pancreas                    5        12.5
# Tail of pancreas                    3         7.5
# Overlapping lesion of pancreas      1         2.5
#
# Summary for 'ajcc_pathologic_stage':
#            Count  Percentage
# Stage IIA     22        55.0
# Stage IB      15        37.5
# Stage I        1         2.5
# Stage IA       1         2.5
# Stage IIB      1         2.5

# %% [markdown]
# # Script for parsing through TCGA data
# Here we take advantage of the "clinical" data attached to TCGA files, which has TNM staging as well as file names. This means we can systematically parse through TCGA data without having to manually curate them which reduces the amount of time needed to navigate through all patients to separate them into controls and interest group.

# %%
# Read the list from list.txt
list_file_path = r" TWA train\List.txt" # Replace with path to TWA train\list.txt

# Read list.txt into a DataFrame
list_df = pd.read_csv(list_file_path, sep='\t')

target_folders = list(list_df['id'])

# Directory path
base_directory = r" \TWA train\Included" # Replace with path to \TWA train\Included

# Create a list to store the DataFrames
dataframes = []
counter = 1

for folder_name in target_folders:
    folder_path = os.path.join(base_directory, folder_name)
    
    # Check if the folder exists
    if os.path.isdir(folder_path):
        # Iterate over the files in the folder
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if os.path.isfile(file_path) and file_name.endswith(".tsv"):
                
                # Create a DataFrame from the file
                df = pd.read_csv(file_path, sep='\t', comment='#', na_values=['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous'])
                df = df.dropna(subset=['gene_id'])
                # Give the DataFrame a name based on the file name
                dataframe_name = f"tw{counter}"
                counter += 1
                
                # Add the DataFrame to the list
                dataframes.append((dataframe_name, df))

# Create a dictionary to store the DataFrames with their respective names
twdf = dict(dataframes)

# %%
# Read the list from list.txt
list_file_path = r" \TMA train\tmatrainall\List.txt" # Replace with path to list.txt

# Read list.txt into a DataFrame
list_df = pd.read_csv(list_file_path, sep='\t')

target_folders = list(list_df['id'])

# Directory path
base_directory = r" \TMA train\tmatrainall\gdc_download_20231222_142835.854848" # Replace with path to gdc_download_20231222_142835.854848

# Create a list to store the DataFrames
dataframes = []
counter = 1

for folder_name in target_folders:
    folder_path = os.path.join(base_directory, folder_name)
    
    # Check if the folder exists
    if os.path.isdir(folder_path):
        # Iterate over the files in the folder
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)
            if os.path.isfile(file_path) and file_name.endswith(".tsv"):
                
                # Create a DataFrame from the file
                df = pd.read_csv(file_path, sep='\t', comment='#', na_values=['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous'])
                df = df.dropna(subset=['gene_id'])
                # Give the DataFrame a name based on the file name
                dataframe_name = f"tm{counter}"
                counter += 1
                
                # Add the DataFrame to the list
                dataframes.append((dataframe_name, df))

# Create a dictionary to store the DataFrames with their respective names
tmdf = dict(dataframes)

# %% [markdown]
# # Prepping of the dataframes

# %%
ftwun = pd.DataFrame() # Prepping TWAs
for i in range(1,39):
    new_column = pd.DataFrame(zip(twdf[f'tw{i}']['unstranded']),columns = [f'tw{i}'])
    ftwun = pd.concat([ftwun, new_column], axis=1)
    
ftmun = pd.DataFrame() # Prepping TMAs (143 patients)
for i in range(1,143):
    new_column = pd.DataFrame(zip(tmdf[f'tm{i}']['unstranded']),columns = [f'tm{i}'])
    ftmun = pd.concat([ftmun, new_column], axis=1)
    
ftwcounts = pd.DataFrame(zip(tmdf['tm1']['gene_id']), columns = ['geneid']) # preparing the gene id column
ffcounts = pd.concat([ftwcounts,ftmun,ftwun], axis= 1) # preparing the counts table for DGE
ffcounts = ffcounts[ffcounts.sum(axis=1)>0] # remove the genes that have 0 counts across all samples
ffcounts = ffcounts.set_index('geneid')
ffcounts = ffcounts.T
m_list = ['d']* 143
w_list = ['c']* 38
condition_list = m_list + w_list
metadata = pd.DataFrame(zip(ffcounts.index, condition_list), columns = ['sample','condition'])
metadata = metadata.set_index('sample')

# %% [markdown]
# # Differential expression all

# %%
ffdds = DeseqDataSet(counts = ffcounts,
                  metadata = metadata,
                  design_factors = 'condition')

# %%
ffdds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.46 seconds.
#
# Fitting dispersions...
# ... done in 18.05 seconds.
#
# Fitting dispersion trend curve...
# ... done in 12.77 seconds.
#
# Fitting MAP dispersions...
# ... done in 24.47 seconds.
#
# Fitting LFCs...
# ... done in 16.54 seconds.
#
# Refitting 2596 outliers.
#
# Fitting dispersions...
# ... done in 1.40 seconds.
#
# Fitting MAP dispersions...
# ... done in 1.43 seconds.
#
# Fitting LFCs...
# ... done in 1.09 seconds.

# %%
ffstat_res = DeseqStats (ffdds, n_cpus = 10, contrast=('condition','d','c'))

# %%
ffstat_res.summary()
# Out:
# Running Wald tests...
# ... done in 8.29 seconds.
# Log2 fold change & Wald test p-value: condition d vs c
#                        baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# geneid
# ENSG00000000003.15  1464.876500       -0.039875  0.109923 -0.362750  0.716791
# ENSG00000000005.6     12.053701       -0.282896  0.339879 -0.832345  0.405214
# ENSG00000000419.13  1264.528422       -0.101801  0.071514 -1.423516  0.154587
# ENSG00000000457.14   975.163783        0.127583  0.098260  1.298429  0.194140
# ENSG00000000460.17   355.198600        0.054917  0.120914  0.454184  0.649697
# ...                         ...             ...       ...       ...       ...
# ENSG00000288667.1     20.405121        0.408095  0.469850  0.868564  0.385086
# ENSG00000288669.1      0.237891       -0.949819  0.882822 -1.075890  0.281976
# ENSG00000288670.1    199.945142       -0.029817  0.084496 -0.352876  0.724181
# ENSG00000288674.1      6.960504        0.051827  0.180505  0.287122  0.774019
# ENSG00000288675.1     19.476931       -0.169948  0.209898 -0.809667  0.418131
#
#                         padj
# geneid
# ENSG00000000003.15  0.876789
# ENSG00000000005.6   0.739055
# ENSG00000000419.13  0.635524
# ENSG00000000457.14  0.656701
# ENSG00000000460.17  0.844856
# ...                      ...
# ENSG00000288667.1   0.731405
# ENSG00000288669.1        NaN
# ENSG00000288670.1   0.880399
# ENSG00000288674.1   0.903623
# ENSG00000288675.1   0.744170
#
# [57097 rows x 6 columns]

# %%
ffres = ffstat_res.results_df

# %%
ffres = pd.merge(ffres,tmdf['tm1'][['gene_id','gene_name']], left_on= ffres.index, right_on='gene_id', how= 'left')

# %%
ffres
# Out:
#           baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  \
# 0      1464.876500       -0.039875  0.109923 -0.362750  0.716791  0.876789
# 1        12.053701       -0.282896  0.339879 -0.832345  0.405214  0.739055
# 2      1264.528422       -0.101801  0.071514 -1.423516  0.154587  0.635524
# 3       975.163783        0.127583  0.098260  1.298429  0.194140  0.656701
# 4       355.198600        0.054917  0.120914  0.454184  0.649697  0.844856
# ...            ...             ...       ...       ...       ...       ...
# 57092    20.405121        0.408095  0.469850  0.868564  0.385086  0.731405
# 57093     0.237891       -0.949819  0.882822 -1.075890  0.281976       NaN
# 57094   199.945142       -0.029817  0.084496 -0.352876  0.724181  0.880399
# 57095     6.960504        0.051827  0.180505  0.287122  0.774019  0.903623
# 57096    19.476931       -0.169948  0.209898 -0.809667  0.418131  0.744170
#
#                   gene_id   gene_name
# 0      ENSG00000000003.15      TSPAN6
# 1       ENSG00000000005.6        TNMD
# 2      ENSG00000000419.13        DPM1
# 3      ENSG00000000457.14       SCYL3
# 4      ENSG00000000460.17    C1orf112
# ...                   ...         ...
# 57092   ENSG00000288667.1  AC078856.1
# 57093   ENSG00000288669.1  AC008763.4
# 57094   ENSG00000288670.1  AL592295.6
# 57095   ENSG00000288674.1  AL391628.1
# 57096   ENSG00000288675.1  AP006621.6
#
# [57097 rows x 8 columns]

# %%
fdegs = ffres[(abs(ffres.log2FoldChange) > 0.5)&(ffres.padj<0.05)]

# %%
fdegs
# Out:
#           baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 195      97.862031        1.235632  0.320159  3.859431  1.136516e-04
# 411     686.920407        1.236756  0.305619  4.046726  5.193893e-05
# 531      18.115533        1.712277  0.336541  5.087871  3.621055e-07
# 863    3635.301336       -0.734857  0.195394 -3.760908  1.692978e-04
# 1237      4.498691       -1.359997  0.351445 -3.869730  1.089561e-04
# ...            ...             ...       ...       ...           ...
# 53367     8.768907        4.952310  0.912801  5.425402  5.782437e-08
# 53494    85.721958        2.168678  0.538928  4.024058  5.720371e-05
# 54591     1.892826        1.093308  0.291147  3.755180  1.732170e-04
# 56095    14.247427        1.982636  0.502009  3.949404  7.834597e-05
# 56842     3.634137        1.793628  0.483134  3.712490  2.052304e-04
#
#            padj            gene_id   gene_name
# 195    0.037748                NaN         NaN
# 411    0.023390                NaN         NaN
# 531    0.000924                NaN         NaN
# 863    0.044481                NaN         NaN
# 1237   0.037573                NaN         NaN
# ...         ...                ...         ...
# 53367  0.000316  ENSG00000280441.3  FP236383.3
# 53494  0.025461  ENSG00000281383.1  FP671120.7
# 54591  0.044481  ENSG00000285567.2  AC074051.3
# 56095  0.030292  ENSG00000287198.1  AC092979.2
# 56842  0.049325  ENSG00000287980.1  AL391557.1
#
# [162 rows x 8 columns]

# %% [markdown]
# # GSEA all

# %%
alranking = ffres[['gene_name','stat']].dropna().sort_values('stat',ascending= False)

# %%
alranking
# Out:
#         gene_name      stat
# 37191   LINC01234  5.716183
# 1874           SI  5.467536
# 17067       POTEF  5.452550
# 53367  FP236383.3  5.425402
# 15155        LIPF  5.388645
# ...           ...       ...
# 21631        CGB8 -5.241861
# 13457        SAA1 -5.319642
# 5516        LYPD3 -5.429008
# 10840      LRRTM1 -6.198468
# 2968         CGB3 -6.294909
#
# [57097 rows x 2 columns]

# %%
pre_res1 = gp.prerank (rnk= alranking, gene_sets = r" Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c2.cp.kegg.v2023.1.Hs.symbols.gmt", min_size = 150) #Replace with path to Gene Sets for KEGG
out1 = []

for term in list(pre_res1.results):
    out1.append([term,
               pre_res1.results[term]['fdr'],
               pre_res1.results[term]['es'],
               pre_res1.results[term]['nes'],
               pre_res1.results[term]['pval'],
                pre_res1.results[term]['matched_genes']])

out_df1 = pd.DataFrame(out1, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df1
# Out:
# 2024-07-08 15:45:46,912 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:45:46,948 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                             Term       fdr        es  \
# 0                               KEGG_ENDOCYTOSIS  0.000000 -0.420897
# 1               KEGG_CHEMOKINE_SIGNALING_PATHWAY  0.000000 -0.369573
# 2                    KEGG_MAPK_SIGNALING_PATHWAY  0.000000 -0.301220
# 3                        KEGG_ALZHEIMERS_DISEASE  0.000000 -0.473796
# 4          KEGG_REGULATION_OF_ACTIN_CYTOSKELETON  0.000000 -0.408600
# 5                            KEGG_FOCAL_ADHESION  0.000000 -0.438219
# 6                       KEGG_HUNTINGTONS_DISEASE  0.000000 -0.475257
# 7                     KEGG_WNT_SIGNALING_PATHWAY  0.000000 -0.306248
# 8                         KEGG_PURINE_METABOLISM  0.000000 -0.385547
# 9                        KEGG_PATHWAYS_IN_CANCER  0.000000 -0.361613
# 10   KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION  0.005416 -0.272340
# 11                KEGG_CALCIUM_SIGNALING_PATHWAY  0.029787 -0.249863
# 12               KEGG_JAK_STAT_SIGNALING_PATHWAY  0.113039 -0.237323
# 13                   KEGG_OLFACTORY_TRANSDUCTION  0.485484  0.250898
# 14  KEGG_NEUROACTIVE_LIGAND_RECEPTOR_INTERACTION  0.543262 -0.192267
#
#          nes      pval                                      matched_genes
# 0  -2.019230  0.000000  HSPA6;HSPA1B;ERBB3;CBLB;HSPA1A;USP8;WWP1;RET;M...
# 1  -1.786135  0.000000  CCL25;XCL1;PLCB4;SOS1;GNG13;PPBP;GRK7;CCL14;PI...
# 2  -1.531637  0.000000  CHP2;HSPA6;MAP3K13;HSPA1B;SOS1;MAPT;HSPA1A;NFA...
# 3  -2.288519  0.000000  CHP2;PLCB4;MAPT;COX6A2;EIF2AK3;COX8C;GRIN1;COX...
# 4  -1.969757  0.000000  CHRM1;ITGA2B;SOS1;DIAPH2;GNA13;ACTN2;PIK3CA;MY...
# 5  -2.144101  0.000000  COL11A2;ITGA2B;CHAD;SOS1;PRKCA;PRKCG;ACTN2;PIK...
# 6  -2.328353  0.000000  SP1;PLCB4;COX6A2;POLR2J3;EP300;COX8C;DNAH3;GRI...
# 7  -1.478729  0.000000  CHP2;WIF1;PLCB4;NFATC2;PRKCA;PRKCG;FZD5;EP300;...
# 8  -1.877097  0.000000  PDE6A;GUCY2C;POLR2J3;PDE10A;PDE7B;PDE8A;POLR2J...
# 9  -1.890532  0.000000  ITGA2B;SOS1;CBLB;PIAS1;PRKCA;PRKCG;FZD5;MECOM;...
# 10 -1.359007  0.000000  TNFSF15;CCL25;XCL1;TNFRSF11B;IL20RB;KITLG;IL23...
# 11 -1.232450  0.039474  CHP2;CHRM1;AVPR1A;PLCB4;ERBB3;PRKCA;PRKCG;CACN...
# 12 -1.142892  0.161290  SOS1;CBLB;IL20RB;PIAS1;EP300;IL23R;SOCS7;CREBB...
# 13  1.000563  0.496439  OR2B2;OR2B6;OR11G2;CLCA1;OR13H1;OR1Q1;OR13C2;O...
# 14 -0.973996  0.606061  TAAR1;OPRK1;CHRM1;AVPR1A;GABRA3;GABRR1;HCRTR1;...

# %%
pre_res2 = gp.prerank (rnk= alranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c3.all.v2023.1.Hs.symbols.gmt", min_size =150) #Replace with path to Gene Sets for C3
out1 = []
out2 = []

for term in list(pre_res2.results):
    out2.append([term,
               pre_res2.results[term]['fdr'],
               pre_res2.results[term]['es'],
               pre_res2.results[term]['nes'],
               pre_res2.results[term]['pval'],
                pre_res2.results[term]['matched_genes']])

out_df2 = pd.DataFrame(out2, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df2
# Out:
# 2024-07-08 15:56:29,720 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:56:29,771 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                        Term       fdr        es       nes      pval  \
# 0                    AP2_Q6  0.000000 -0.361935 -1.781865  0.000000
# 1                  TFIIA_Q6  0.000000 -0.390252 -2.031401  0.000000
# 2                   MIR4447  0.000000 -0.484619 -2.543575  0.000000
# 3                MIR4725_3P  0.000000 -0.369015 -1.852981  0.000000
# 4                 MIR149_3P  0.000000 -0.483022 -2.491935  0.000000
# ...                     ...       ...       ...       ...       ...
# 1268                MIR9986  0.963220  0.203399  0.760870  0.930736
# 1269                MIR1294  0.964147  0.202345  0.757955  0.938445
# 1270              MIR509_5P  0.967624  0.199604  0.751597  0.935106
# 1271                 SRY_02  0.968761  0.193054  0.748229  0.968685
# 1272  GACTGTT_MIR212_MIR132  0.982233  0.191119  0.722425  0.971708
#
#                                           matched_genes
# 0     COL11A2;ARHGAP36;CLC;PABPC3;WAC;KCNH5;FZD5;FNB...
# 1     HOXA9;RNF38;NFIB;CLUL1;SLC39A5;INO80;EP300;BTB...
# 2     CNDP1;AVPR1A;MTCL1;AKAP13;PLEKHM3;C20orf203;CA...
# 3     CSNK1G1;SP1;ZNF609;GPA33;HOXB9;FNBP1L;INO80D;E...
# 4     NOX1;COL11A2;ALPG;SV2C;SRRM4;RNF38;MAPT;CASP10...
# ...                                                 ...
# 1268  KRT20;FIGN;KLHL24;CTBP2;DIABLO;YOD1;LIMD1;GXYL...
# 1269  KRT20;FIGN;KLHL24;CTBP2;DIABLO;YOD1;LIMD1;GXYL...
# 1270  SHISA9;NHEJ1;FIGN;INO80D;GOLGA1;CDC14A;DOCK3;T...
# 1271  EPHA7;MSI2;PPM1D;RBFOX1;NFIB;PIAS1;NR4A3;ZNF66...
# 1272  EP300;FOXA1;H3-5;RFX3;CTDSPL2;NR4A2;PTBP2;FEM1...
#
# [1273 rows x 6 columns]

# %%
pre_res3 = gp.prerank (rnk= alranking, gene_sets = r" \Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c3.mir.v2023.1.Hs.symbols.gmt", min_size = 150) #Replace with path 
out1 = []
out3 = []

for term in list(pre_res3.results):
    out3.append([term,
               pre_res3.results[term]['fdr'],
               pre_res3.results[term]['es'],
               pre_res3.results[term]['nes'],
               pre_res3.results[term]['pval'],
                pre_res3.results[term]['matched_genes']])

out_df3 = pd.DataFrame(out3, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df3
# Out:
# 2024-07-08 15:46:04,010 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:46:04,046 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                       Term       fdr        es       nes      pval  \
# 0               MIR6887_3P  0.000000 -0.377183 -1.855085  0.000000
# 1               MIR6883_5P  0.000000 -0.469409 -2.466501  0.000000
# 2               MIR4725_3P  0.000000 -0.369015 -1.852981  0.000000
# 3                  MIR4271  0.000000 -0.404024 -1.953154  0.000000
# 4           CCTGCTG_MIR214  0.000000 -0.355218 -1.808752  0.000000
# ..                     ...       ...       ...       ...       ...
# 743            MIR509_3_5P  0.958080  0.204374  0.767147  0.927273
# 744                MIR9986  0.961749  0.203399  0.760870  0.930736
# 745                MIR1294  0.962484  0.202345  0.757955  0.938445
# 746              MIR509_5P  0.965811  0.199604  0.751597  0.935106
# 747  GACTGTT_MIR212_MIR132  0.981546  0.191119  0.722425  0.971708
#
#                                          matched_genes
# 0    MS4A15;CNPY2;PPP4R3A;SRCIN1;TET3;MYO10;RND1;PC...
# 1    NOX1;COL11A2;ALPG;SV2C;SRRM4;RNF38;MAPT;CASP10...
# 2    CSNK1G1;SP1;ZNF609;GPA33;HOXB9;FNBP1L;INO80D;E...
# 3    CSNK1G1;FNBP1L;INO80D;EP300;TET3;BCAS3;KCNA1;Z...
# 4    MOG;ATP8B5P;PLCB4;TUBA4B;ZNF609;MID1;MAPT;ARPP...
# ..                                                 ...
# 743  SHISA9;NHEJ1;FIGN;INO80D;GOLGA1;CDC14A;DOCK3;T...
# 744  KRT20;FIGN;KLHL24;CTBP2;DIABLO;YOD1;LIMD1;GXYL...
# 745  KRT20;FIGN;KLHL24;CTBP2;DIABLO;YOD1;LIMD1;GXYL...
# 746  SHISA9;NHEJ1;FIGN;INO80D;GOLGA1;CDC14A;DOCK3;T...
# 747  EP300;FOXA1;H3-5;RFX3;CTDSPL2;NR4A2;PTBP2;FEM1...
#
# [748 rows x 6 columns]

# %%
pre_res4 = gp.prerank (rnk= alranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c3.tft.v2023.1.Hs.symbols.gmt", min_size = 150) #Replace with path 
out4 = []

for term in list(pre_res4.results):
    out4.append([term,
               pre_res4.results[term]['fdr'],
               pre_res4.results[term]['es'],
               pre_res4.results[term]['nes'],
               pre_res4.results[term]['pval'],
                pre_res4.results[term]['matched_genes']])

out_df4 = pd.DataFrame(out4, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df4
# Out:
# 2024-07-08 15:47:32,042 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:47:32,087 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                Term  fdr        es       nes      pval  \
# 0         SREBP1_Q6  0.0 -0.371961 -1.845001  0.000000
# 1           NFE2_01  0.0 -0.434684 -2.197457  0.000000
# 2            MAZ_Q6  0.0 -0.401309 -1.939083  0.000000
# 3       COUP_DR1_Q6  0.0 -0.397253 -1.997677  0.000000
# 4             ATF_B  0.0 -0.425124 -2.107892  0.000000
# ..              ...  ...       ...       ...       ...
# 520        NKX22_01  1.0  0.251163  0.956938  0.588608
# 521         OCT1_07  1.0  0.314141  1.186549  0.132686
# 522        STAT6_01  1.0  0.266302  1.044587  0.367662
# 523        CART1_01  1.0  0.331624  1.290051  0.027055
# 524  GATAAGR_GATA_C  1.0  0.240335  0.946957  0.632444
#
#                                          matched_genes
# 0    IGF2BP1;SRRM4;KMT2E;HOXA11;GUCA2B;SLC4A1;RBFOX...
# 1    MYB;DOC2A;CLC;HOXA11;SV2B;TUBA4B;CA7;VEZF1;CAP...
# 2    UPF2;TSSK3;WAC;HCRTR1;FNBP1L;UBE4B;CELF1;PTPN5...
# 3    SLC26A3;MTTP;PAX7;FABP1;ADAMTS19;FXYD1;RBBP6;S...
# 4    MAP3K13;VIP;SRRM4;CLDN6;NR2E1;FOXD3;GPM6B;DEPD...
# ..                                                 ...
# 520  PHOX2B;NKX2-8;CHRM1;MIR137HG;FNBP1L;GOLGA1;NED...
# 521  PHOX2B;CSNK1G1;ATOH1;MID1;HEPACAM;BTBD3;BRD8;M...
# 522  PHOX2B;VIP;PTCHD1;GSTT4;GAREM1;TMC1;KDM6A;TNFR...
# 523  SLC26A3;EPHA7;PHOX2B;LOXHD1;UNC13B;HOXA11;LGAL...
# 524  SPINK4;FABP2;KRT20;GUCA2A;SOX10;TDRD5;GFRA3;SL...
#
# [525 rows x 6 columns]

# %%
pre_res6 = gp.prerank (rnk= alranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c5.go.bp.v2023.1.Hs.symbols.gmt", min_size = 150) #Replace with path 
out6 = []

for term in list(pre_res6.results):
    out6.append([term,
               pre_res6.results[term]['fdr'],
               pre_res6.results[term]['es'],
               pre_res6.results[term]['nes'],
               pre_res6.results[term]['pval'],
                pre_res6.results[term]['matched_genes']])

out_df6 = pd.DataFrame(out6, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df6
# Out:
# 2024-07-08 15:48:53,316 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:48:53,356 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                                   Term  fdr        es  \
# 0    GOBP_NEGATIVE_REGULATION_OF_LYMPHOCYTE_ACTIVATION  0.0 -0.417643
# 1             GOBP_REGULATION_OF_LYMPHOCYTE_ACTIVATION  0.0 -0.368318
# 2                    GOBP_KERATINOCYTE_DIFFERENTIATION  0.0 -0.440109
# 3               GOBP_INTRACELLULAR_GLUCOSE_HOMEOSTASIS  0.0 -0.367917
# 4          GOBP_NEGATIVE_REGULATION_OF_IMMUNE_RESPONSE  0.0 -0.432734
# ..                                                 ...  ...       ...
# 659                          GOBP_SINGLE_FERTILIZATION  1.0  0.252192
# 660              GOBP_RESPONSE_TO_TEMPERATURE_STIMULUS  1.0  0.278131
# 661                                 GOBP_FERTILIZATION  1.0  0.226971
# 662                 GOBP_MONOCARBOXYLIC_ACID_TRANSPORT  1.0  0.226198
# 663                   GOBP_SENSORY_PERCEPTION_OF_SMELL  1.0  0.243442
#
#           nes      pval                                      matched_genes
# 0   -2.021690  0.000000  XCL1;CBLB;IL20RB;PAWR;VTCN1;PLA2G2F;CTSG;IL4;T...
# 1   -1.965632  0.000000  PCK1;XCL1;CLC;VCAM1;SOS1;CGAS;CBLB;IL20RB;HSPH...
# 2   -2.137523  0.000000  KRT73;CDSN;FOXN1;EXPH5;LIPK;KRT72;UGCG;REG3A;L...
# 3   -1.728079  0.000000  PCK1;OPRK1;UNC13B;TRA2B;CMA1;SIN3A;GHRHR;PIK3C...
# 4   -2.147073  0.000000  XCL1;IL20RB;NPY5R;ENPP3;GPR17;ACOD1;IL33;IL4;U...
# ..        ...       ...                                                ...
# 659  0.944893  0.621912  HOXA9;UNC13B;HOXA11;ZAN;RNASE10;RIMS1;PRND;IZU...
# 660  1.053961  0.355932  HSPA6;HSP90AA2P;HSP90AA4P;PIRT;CHORDC1;DNAJB4;...
# 661  0.868513  0.790698  SYCP2;HOXA9;UNC13B;HOXA11;ZAN;RNASE10;RIMS1;KL...
# 662  0.864442  0.794055  SLC10A2;SPX;FABP7;FABP2;FABP1;FABP9;CYP4F2;SLC...
# 663  0.979989  0.579798  OR2B2;OR2B6;OR11G2;OBP2B;OR13H1;OR14K1;OR1Q1;O...
#
# [664 rows x 6 columns]

# %%
pre_res7 = gp.prerank (rnk= alranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c5.go.cc.v2023.1.Hs.symbols.gmt", min_size = 150) #Replace with path 
out7= []

for term in list(pre_res7.results):
    out7.append([term,
               pre_res7.results[term]['fdr'],
               pre_res7.results[term]['es'],
               pre_res7.results[term]['nes'],
               pre_res7.results[term]['pval'],
                pre_res7.results[term]['matched_genes']])

out_df7 = pd.DataFrame(out7, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df7
# Out:
# 2024-07-08 15:50:48,312 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:50:48,359 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                                Term  fdr        es       nes  \
# 0                                  GOCC_MICROTUBULE  0.0 -0.334735 -1.818264
# 1                  GOCC_ENDOPLASMIC_RETICULUM_LUMEN  0.0 -0.515451 -2.612458
# 2                  GOCC_POSTSYNAPTIC_SPECIALIZATION  0.0 -0.310812 -1.634858
# 3                                      GOCC_SPINDLE  0.0 -0.398924 -2.167102
# 4                                GOCC_LATE_ENDOSOME  0.0 -0.424751 -2.189755
# ..                                              ...  ...       ...       ...
# 93                           GOCC_NON_MOTILE_CILIUM  1.0  0.235918  0.896525
# 94     GOCC_CLUSTER_OF_ACTIN_BASED_CELL_PROJECTIONS  1.0  0.271817  1.021295
# 95                                   GOCC_CENTRIOLE  1.0  0.246600  0.926171
# 96  GOCC_PLASMA_MEMBRANE_SIGNALING_RECEPTOR_COMPLEX  1.0  0.198664  0.783502
# 97                               GOCC_MOTILE_CILIUM  1.0  0.245261  0.956999
#
#         pval                                      matched_genes
# 0   0.000000  TUBGCP4;TTLL9;TUBA4B;HSPH1;MID1;MAPT;WHAMM;FIG...
# 1   0.000000  MTTP;COL11A2;COL28A1;APOA4;APOA5;ARSH;RDH5;FGA...
# 2   0.000000  EPHA7;ARC;CHRM1;SHISA9;CRIPT;SOS1;GABRA3;GAP43...
# 3   0.000000  TUBGCP4;MID1;MBIP;TFDP2;MTCL1;INO80;CCDC117;CD...
# 4   0.000000  SFTPB;NAPSA;APOA5;SLC17A8;ASTN2;OSBPL1A;SFTPC;...
# ..       ...                                                ...
# 93  0.703545  PDE6A;CNGA1;SHANK2;PKD1L1;STRCP1;STRC;CDC14A;G...
# 94  0.457573  SI;SLC26A3;TMPRSS15;MTTP;ITLN1;SLC28A1;SLC7A9;...
# 95  0.663399  HSPA6;HSPA1B;HSPA1A;OFD1;IFT81;KIF24;CEP295NL;...
# 96  0.943147  SHISA9;ITGA2B;ERBB3;TRBV20-1;TRBV29-1;IL23R;GR...
# 97  0.589691  SLC26A3;CATSPERG;TTLL9;RNF38;QRICH2;CFAP47;DNA...
#
# [98 rows x 6 columns]

# %%
pre_res8 = gp.prerank (rnk= alranking, gene_sets = "GO_Molecular_Function_2023", min_size = 150) # Integrated path in GSEA (NO NEED TO REPLACE)
out8 = []

for term in list(pre_res8.results):
    out8.append([term,
               pre_res8.results[term]['fdr'],
               pre_res8.results[term]['es'],
               pre_res8.results[term]['nes'],
               pre_res8.results[term]['pval'],
                pre_res8.results[term]['matched_genes']])

out_df8 = pd.DataFrame(out8, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df8
# Out:
# 2024-07-08 15:51:12,177 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:51:12,214 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                                  Term       fdr        es  \
# 0          Adenyl Ribonucleotide Binding (GO:0032559)  0.000000 -0.286961
# 1                    Calcium Ion Binding (GO:0005509)  0.000000 -0.314597
# 2   Ribonucleoside Triphosphate Phosphatase Activi...  0.000000 -0.454099
# 3   Ubiquitin-Like Protein Transferase Activity (G...  0.000000 -0.329593
# 4                          Actin Binding (GO:0003779)  0.000000 -0.460919
# 5                       Zinc Ion Binding (GO:0008270)  0.000000 -0.290867
# 6                         GTPase Binding (GO:0051020)  0.000000 -0.355978
# 7   Purine Ribonucleoside Triphosphate Binding (GO...  0.000000 -0.355152
# 8               Receptor Ligand Activity (GO:0048018)  0.000000 -0.384013
# 9                        Tubulin Binding (GO:0015631)  0.000000 -0.322959
# 10             GTPase Regulator Activity (GO:0030695)  0.000000 -0.317442
# 11      Ubiquitin Protein Ligase Binding (GO:0031625)  0.000000 -0.374690
# 12   Protein Heterodimerization Activity (GO:0046982)  0.000000 -0.329258
# 13                           ATP Binding (GO:0005524)  0.000000 -0.283146
# 14                  Small GTPase Binding (GO:0031267)  0.000000 -0.357478
# 15                           GTP Binding (GO:0005525)  0.000000 -0.491195
# 16                        Kinase Binding (GO:0019900)  0.000000 -0.383567
# 17                      Cadherin Binding (GO:0045296)  0.000000 -0.488676
# 18                 Magnesium Ion Binding (GO:0000287)  0.000000 -0.335896
# 19                       GTPase Activity (GO:0003924)  0.000000 -0.453547
# 20                     Cytokine Activity (GO:0005125)  0.000000 -0.331783
# 21  DNA-binding Transcription Factor Binding (GO:0...  0.000000 -0.362588
# 22          Transition Metal Ion Binding (GO:0046914)  0.000000 -0.330138
# 23  RNA Polymerase II-specific DNA-binding Transcr...  0.000000 -0.300805
# 24   G Protein-Coupled Receptor Activity (GO:0004930)  0.000000 -0.280175
# 25  Ubiquitin-Like Protein Ligase Binding (GO:0044...  0.000000 -0.384244
# 26  Guanyl-Nucleotide Exchange Factor Activity (GO...  0.000000 -0.325930
# 27  Ubiquitin-Protein Transferase Activity (GO:000...  0.000000 -0.293817
# 28                   Microtubule Binding (GO:0008017)  0.000000 -0.343898
# 29                Endopeptidase Activity (GO:0004175)  0.000000 -0.331392
# 30         Guanyl Ribonucleotide Binding (GO:0032561)  0.000000 -0.468124
# 31             GTPase Activator Activity (GO:0005096)  0.000865 -0.283076
# 32  Ubiquitin-Like Protein Ligase Activity (GO:006...  0.005032 -0.247799
# 33  Protein Serine/Threonine Kinase Activity (GO:0...  0.007117 -0.250218
# 34     Ubiquitin Protein Ligase Activity (GO:0061630)  0.007326 -0.244379
# 35  Transcription Regulatory Region Nucleic Acid B...  0.008457 -0.257886
# 36                          mRNA Binding (GO:0003729)  0.015708 -0.241979
# 37  Transcription Cis-Regulatory Region Binding (G...  0.057538 -0.215273
# 38  DNA-binding Transcription Repressor Activity, ...  0.839983  0.220847
# 39  DNA-binding Transcription Activator Activity, ...  0.951472  0.239466
# 40           Olfactory Receptor Activity (GO:0004984)  1.000000  0.261328
#
#          nes      pval                                      matched_genes
# 0  -1.478001  0.000000  ABCG5;HSP90AA2P;HSP90AA4P;WNK4;ABCG8;ATP1A2;HS...
# 1  -1.633838  0.000000  CHP2;ITLN1;CDH26;SCUBE1;CPNE6;LRP2;CLEC6A;TPT1...
# 2  -2.293649  0.000000  AGAP7P;RGS2;RGS5;RGS8;RAB6C;RND1;DDX3X;GNA13;N...
# 3  -1.660340  0.000000  MYLIP;RBBP6;RNF186;ARIH1;BRAP;PIAS1;HUWE1;WWP1...
# 4  -2.306318  0.000000  PIP;MAPT;PAWR;COBL;MICAL3;LMOD3;AVIL;HNRNPU;MY...
# 5  -1.508001  0.000000  TAB3;CHORDC1;NPEPPSP1;ADH6;CBLB;ARIH1;ADH1C;AL...
# 6  -1.783698  0.000000  NOX1;UNC13B;FNBP1L;WHAMM;RIMS1;EXPH5;AKAP13;US...
# 7  -1.901530  0.000000  PCK1;ABCG5;HSP90AA2P;HSP90AA4P;WNK4;ABCG8;ATP1...
# 8  -2.008234  0.000000  EPHA7;VIP;CCL25;GUCA2A;TDGF1;NPPB;BMP3;HSPA1A;...
# 9  -1.638856  0.000000  TUBGCP4;CRIPT;STMN4;TTLL9;MID1;MAPT;MTCL1;WHAM...
# 10 -1.666277  0.000000  DEFA6;RGPD5;SRGAP1;AGAP7P;SOS1;FAM13A;RGS2;DNM...
# 11 -1.871777  0.000000  HSPA6;RPS27AP5;HSPA1B;RNF186;PRKAR2B;ERBB3;ARI...
# 12 -1.629399  0.000000  ABCG5;MTTP;ABCG8;ATP1A2;SLC7A9;ERBB3;NEUROD2;R...
# 13 -1.426424  0.000000  ABCG5;HSP90AA2P;HSP90AA4P;WNK4;ABCG8;ATP1A2;HS...
# 14 -1.804275  0.000000  NOX1;UNC13B;WHAMM;RIMS1;EXPH5;AKAP13;USP6NL;DO...
# 15 -2.413624  0.000000  PCK1;TUBA4B;RND1;TUBE1;ARL5B;TUBAL3;RRAGB;TUBD...
# 16 -1.961735  0.000000  POTEF;POTEE;MAP3K13;TOM1L1;CHIA;RBBP6;SPDYE17;...
# 17 -2.436224  0.000000  CDH26;UBAP2;MRTFB;TJP1;HSPA1A;FNBP1L;USP8;NCK1...
# 18 -1.612046  0.000000  PCK1;DYRK3;TSSK3;ALPI;PLSCR1;ATP4A;MTPAP;STK38...
# 19 -2.278054  0.000000  AGAP7P;RGS2;RGS5;RGS8;RAB6C;RND1;DDX3X;GNA13;N...
# 20 -1.617929  0.000000  CCL25;XCL1;BMP3;MSTN;KITLG;PPBP;CCL14;IFNG;GDF...
# 21 -1.896465  0.000000  NKX2-1;SPEN;ESRRB;UBXN7;EP300;CCNT1;NHLH2;CTBP...
# 22 -1.756511  0.000000  PCK1;TAB3;CHORDC1;NPEPPSP1;ADH6;APOA4;CBLB;ARI...
# 23 -1.481447  0.000000  NKX2-1;SPEN;ESRRB;NCOA7;UBXN7;EP300;NHLH2;BCAS...
# 24 -1.438537  0.000000  TAAR1;OPRK1;ADGRD2;HCRTR1;GALR1;RGR;GRM3;ADGRB...
# 25 -1.935527  0.000000  HSPA6;RPS27AP5;HSPA1B;RNF186;PRKAR2B;ERBB3;ARI...
# 26 -1.590126  0.000000  DEFA6;SOS1;DNMBP;RASGEF1C;AKAP13;RAB3IP;GNA13;...
# 27 -1.567912  0.000000  TRIM72;MYLIP;RBBP6;RNF186;RNF38;RNF111;CBLB;AR...
# 28 -1.762717  0.000000  TUBGCP4;CRIPT;MID1;MAPT;MTCL1;WHAMM;KIF1B;MTUS...
# 29 -1.756584  0.000000  PIP;KLK12;NAPSA;ADAMTS19;CLCA1;MEP1A;CASP10;US...
# 30 -2.337949  0.000000  PCK1;CNGA1;TUBA4B;PDE10A;RND1;TUBE1;ARL5B;TUBA...
# 31 -1.398441  0.000000  RGPD5;SRGAP1;AGAP7P;SOS1;FAM13A;RGS2;RGS5;ELMO...
# 32 -1.299370  0.000000  TRIM72;MYLIP;RBBP6;RNF186;RNF38;RNF111;CBLB;AR...
# 33 -1.283669  0.000000  MAP3K13;WNK4;PPM1D;CSNK1G1;DYRK3;TSSK3;LMTK2;T...
# 34 -1.290113  0.000000  TRIM72;MYLIP;RBBP6;RNF186;RNF38;RNF111;CBLB;AR...
# 35 -1.272283  0.000000  GATA5;NKX2-1;ATOH7;SOX10;CDX1;KLF11;CALCOCO1;F...
# 36 -1.234972  0.000000  IGF2BP1;MSI2;SRRM4;PABPC3;SPEN;RBFOX1;ATXN2;IR...
# 37 -1.161376  0.000000  GATA5;ISX;PHOX2B;NKX2-1;ATOH7;SOX10;CDX1;ESRRB...
# 38  0.858662  0.826310  ZFP57;HOXB13;ZNF619;CDX2;ZBTB5;ZNF140;ZSCAN2;Z...
# 39  0.946822  0.657084  PHOX2B;NKX2-8;MYB;SOX10;CDX1;ESRRB;NFIB;USF3;P...
# 40  1.037840  0.376531  OR2B2;OR2B6;OR13H1;OR14K1;OR1Q1;OR13C2;OR1N2;O...

# %%
pre_res9 = gp.prerank (rnk= alranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c5.hpo.v2023.1.Hs.symbols.gmt", min_size = 150) #Replace with path 
out9= []

for term in list(pre_res9.results):
    out9.append([term,
               pre_res9.results[term]['fdr'],
               pre_res9.results[term]['es'],
               pre_res9.results[term]['nes'],
               pre_res9.results[term]['pval'],
                pre_res9.results[term]['matched_genes']])

out_df9 = pd.DataFrame(out9, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df9
# Out:
# 2024-07-08 15:51:23,337 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:51:23,374 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                                   Term       fdr        es  \
# 0                         HP_ABNORMALITY_OF_THE_LARYNX  0.000000 -0.316205
# 1    HP_DEVIATION_OF_THE_HAND_OR_OF_FINGERS_OF_THE_...  0.000000 -0.340512
# 2                 HP_ABNORMAL_CHORIORETINAL_MORPHOLOGY  0.000000 -0.358851
# 3                       HP_ABNORMAL_EYELASH_MORPHOLOGY  0.000000 -0.411255
# 4                               HP_FINGER_CLINODACTYLY  0.000000 -0.327783
# ..                                                 ...       ...       ...
# 585                  HP_ABNORMALITY_OF_THE_TESTIS_SIZE  0.931030  0.223870
# 586                        HP_THIN_UPPER_LIP_VERMILION  0.952212  0.227326
# 587              HP_ABNORMALITY_OF_THE_PITUITARY_GLAND  1.000000  0.225423
# 588                    HP_DECREASED_FERTILITY_IN_MALES  1.000000  0.310729
# 589                      HP_ABNORMAL_ELECTRORETINOGRAM  1.000000  0.240437
#
#           nes      pval                                      matched_genes
# 0   -1.588333  0.000000  PPM1D;MID1;ATXN2;KANSL1;EP300;KAT6B;XPNPEP2;RS...
# 1   -1.735286  0.000000  GATA5;DPYSL5;L1CAM;HOXA11;CRIPT;SPEN;SOS1;HOXA...
# 2   -1.710541  0.000000  RPE65;TUBGCP4;WAC;HHAT;ADAMTS18;CHD7;CRX;CASK;...
# 3   -2.107857  0.000000  SOX10;KDM6A;TUBGCP4;SPEN;TERC;EP300;CREBBP;SLC...
# 4   -1.724444  0.000000  GATA5;L1CAM;HOXA11;SPEN;SOS1;HOXA13;H19;MECOM;...
# ..        ...       ...                                                ...
# 585  0.852847  0.799787  SOX10;PROK2;NR5A1;KLHL10;RSPO1;FLRT3;IL17RD;PM...
# 586  0.891792  0.767109  PPM1D;SPEN;WAC;MID1;HUWE1;BPTF;EP300;KAT6B;CRE...
# 587  0.894716  0.801829  NKX2-1;SOX10;PROK2;TDGF1;KCNJ18;APOA5;KANSL1;U...
# 588  1.187461  0.138889  SYCP2;QRICH2;CFAP47;DNAH10;NR5A1;GCNA;STRC;CDC...
# 589  0.923991  0.660338  RPE65;PDE6A;MT-TS2;CNGA1;ACOX1;KIZ;GPR179;NMNA...
#
# [590 rows x 6 columns]

# %%
pre_res10 = gp.prerank (rnk= alranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c6.all.v2023.1.Hs.symbols.gmt", min_size = 150) #Replace with path 
out10 = []

for term in list(pre_res10.results):
    out10.append([term,
               pre_res10.results[term]['fdr'],
               pre_res10.results[term]['es'],
               pre_res10.results[term]['nes'],
               pre_res10.results[term]['pval'],
                pre_res10.results[term]['matched_genes']])

out_df10 = pd.DataFrame(out10, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df10
# Out:
# 2024-07-08 15:53:17,335 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:53:17,376 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                        Term  fdr        es       nes      pval  \
# 0    GCNP_SHH_UP_LATE.V1_DN  0.0 -0.514929 -2.470027  0.000000
# 1              AKT_UP.V1_DN  0.0 -0.424115 -2.023406  0.000000
# 2      ESC_J1_UP_LATE.V1_UP  0.0 -0.350989 -1.685751  0.000000
# 3              SRC_UP.V1_DN  0.0 -0.355448 -1.717148  0.000000
# 4              WNT_UP.V1_UP  0.0 -0.433513 -2.094521  0.000000
# ..                      ...  ...       ...       ...       ...
# 105            IL2_UP.V1_DN  1.0  0.218355  0.836359  0.836735
# 106       PRC1_BMI_UP.V1_UP  1.0  0.228102  0.872110  0.779894
# 107           PTEN_DN.V1_UP  1.0  0.226084  0.863938  0.809024
# 108           LTE2_UP.V1_DN  1.0  0.222384  0.852636  0.819810
# 109       PRC2_EED_DN.V1_UP  1.0  0.234528  0.900555  0.710021
#
#                                          matched_genes
# 0    RBBP6;NCOA7;TUBA4B;COX6A2;LGALS2;FOXD3;KPNA1;S...
# 1    SLC18A1;WIF1;FXYD1;CHAD;FMO2;SH3BGR;MSL2;PADI3...
# 2    MTTP;H19;LGALS2;TDRD7;ANKRD1;CA4;ESX1;MYO6;RAB...
# 3    GFRA3;EIF3CL;CA7;KCNMB3;CAPN12;NPY5R;ZNF436;CO...
# 4    CPS1;TEN1;CLDN6;RETNLB;NEUROD2;ADGRB1;RSPO1;KC...
# ..                                                 ...
# 105  LIPF;FUT9;CLCA1;ZNF695;CUX2;RGS2;LINC00472;CAC...
# 106  ACTL8;CYP2B6;PDE6A;CLCA1;CNGA1;AOC4P;RFPL2;CCN...
# 107  DEFA5;INSL4;VCAM1;PRKAR2B;H1-6;RGS2;NGB;FNBP1L...
# 108  PRKAR2B;ZNF140;MTCL1;MYO10;TDRD7;PLSCR1;ZNF84;...
# 109  SLC28A1;NMT2;CLCA1;CNGA1;RNF38;GSTA3;RFPL2;RGR...
#
# [110 rows x 6 columns]

# %%
pre_res12 = gp.prerank (rnk= alranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\h.all.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out12= []

for term in list(pre_res12.results):
    out12.append([term,
               pre_res12.results[term]['fdr'],
               pre_res12.results[term]['es'],
               pre_res12.results[term]['nes'],
               pre_res12.results[term]['pval'],
                pre_res12.results[term]['matched_genes']])

out_df12 = pd.DataFrame(out12, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df12
# Out:
# 2024-07-08 15:53:45,477 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:53:45,512 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                           Term       fdr        es       nes  \
# 0                     HALLMARK_APICAL_JUNCTION  0.000000 -0.535870 -2.571983
# 1                      HALLMARK_APICAL_SURFACE  0.000000 -0.536696 -2.087105
# 2                      HALLMARK_MYC_TARGETS_V2  0.000000 -0.553402 -2.293844
# 3           HALLMARK_OXIDATIVE_PHOSPHORYLATION  0.000000 -0.626151 -3.146072
# 4                    HALLMARK_MTORC1_SIGNALING  0.000000 -0.532525 -2.561539
# 5                             HALLMARK_HYPOXIA  0.000000 -0.449141 -2.199355
# 6                          HALLMARK_GLYCOLYSIS  0.000000 -0.553309 -2.730467
# 7             HALLMARK_CHOLESTEROL_HOMEOSTASIS  0.000000 -0.509600 -2.208704
# 8                          HALLMARK_DNA_REPAIR  0.000000 -0.621158 -2.940335
# 9                          HALLMARK_MYOGENESIS  0.000000 -0.426916 -2.091949
# 10                    HALLMARK_NOTCH_SIGNALING  0.000000 -0.532607 -1.952199
# 11                     HALLMARK_MYC_TARGETS_V1  0.000000 -0.592411 -2.926525
# 12                        HALLMARK_P53_PATHWAY  0.000000 -0.543241 -2.687777
# 13             HALLMARK_ESTROGEN_RESPONSE_LATE  0.000000 -0.481530 -2.339374
# 14                        HALLMARK_COAGULATION  0.000000 -0.485992 -2.309443
# 15                HALLMARK_ALLOGRAFT_REJECTION  0.000000 -0.400628 -2.041289
# 16            HALLMARK_TNFA_SIGNALING_VIA_NFKB  0.000000 -0.474520 -2.402050
# 17                          HALLMARK_APOPTOSIS  0.000000 -0.490785 -2.427678
# 18                         HALLMARK_COMPLEMENT  0.000000 -0.417294 -2.116271
# 19    HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY  0.000000 -0.618699 -2.392978
# 20                HALLMARK_IL2_STAT5_SIGNALING  0.000000 -0.431610 -2.152340
# 21                        HALLMARK_E2F_TARGETS  0.000000 -0.594227 -2.969694
# 22                       HALLMARK_ANGIOGENESIS  0.000000 -0.534336 -1.950993
# 23          HALLMARK_UNFOLDED_PROTEIN_RESPONSE  0.000000 -0.474455 -2.199751
# 24                       HALLMARK_ADIPOGENESIS  0.000000 -0.476085 -2.356831
# 25                         HALLMARK_PEROXISOME  0.000000 -0.462606 -2.094945
# 26                     HALLMARK_G2M_CHECKPOINT  0.000000 -0.480562 -2.366297
# 27                HALLMARK_PANCREAS_BETA_CELLS  0.000000 -0.520182 -2.001434
# 28            HALLMARK_PI3K_AKT_MTOR_SIGNALING  0.000000 -0.460945 -2.065812
# 29          HALLMARK_INTERFERON_GAMMA_RESPONSE  0.000000 -0.405851 -1.949830
# 30            HALLMARK_ESTROGEN_RESPONSE_EARLY  0.000000 -0.409582 -2.014180
# 31  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.000000 -0.635625 -3.139979
# 32                     HALLMARK_UV_RESPONSE_UP  0.000000 -0.509511 -2.456780
# 33            HALLMARK_IL6_JAK_STAT3_SIGNALING  0.000300 -0.442335 -1.878793
# 34                    HALLMARK_MITOTIC_SPINDLE  0.000308 -0.375145 -1.894964
# 35              HALLMARK_XENOBIOTIC_METABOLISM  0.000552 -0.369352 -1.843409
# 36              HALLMARK_INFLAMMATORY_RESPONSE  0.000567 -0.372528 -1.853957
# 37         HALLMARK_WNT_BETA_CATENIN_SIGNALING  0.000583 -0.488118 -1.856616
# 38                 HALLMARK_HEDGEHOG_SIGNALING  0.000787 -0.472214 -1.733631
# 39              HALLMARK_FATTY_ACID_METABOLISM  0.000807 -0.361446 -1.765875
# 40                  HALLMARK_ANDROGEN_RESPONSE  0.001498 -0.367351 -1.682644
# 41                 HALLMARK_TGF_BETA_SIGNALING  0.001535 -0.409334 -1.688949
# 42                  HALLMARK_KRAS_SIGNALING_UP  0.002439 -0.342937 -1.666727
# 43                  HALLMARK_PROTEIN_SECRETION  0.004429 -0.354555 -1.608696
# 44                    HALLMARK_HEME_METABOLISM  0.004529 -0.331234 -1.609229
# 45          HALLMARK_INTERFERON_ALPHA_RESPONSE  0.007981 -0.345219 -1.528708
# 46               HALLMARK_BILE_ACID_METABOLISM  0.023209 -0.304160 -1.382017
# 47                  HALLMARK_KRAS_SIGNALING_DN  0.221357 -0.221920 -1.104118
# 48                     HALLMARK_UV_RESPONSE_DN  0.470317 -0.207816 -0.992672
# 49                    HALLMARK_SPERMATOGENESIS  0.473279 -0.214583 -0.994214
#
#         pval                                      matched_genes
# 0   0.000000  WNK4;VCAM1;CLDN6;TNFRSF11B;CADM2;TJP1;CDSN;ACT...
# 1   0.000000  SCUBE1;PKHD1;GSTM3;AKAP7;CD160;GATA3;ATP8B1;RH...
# 2   0.000000  TMEM97;HSPD1;HSPE1;WDR43;NOP2;UTP20;RCL1;SORD;...
# 3   0.000000  PDHX;COX11;FXN;ETFDH;IDH3A;SDHA;MTRR;ABCB7;ALD...
# 4   0.000000  TMEM97;IFRD1;TBK1;HSPD1;TXNRD1;HSPE1;IFI30;ASN...
# 5   0.000000  PCK1;KDM3A;HOXB9;PRKCA;KLHL24;NOCT;LDHC;TIPARP...
# 6   0.000000  LCT;DSC2;FBP2;PMM2;LDHC;GNE;ZNF292;PPFIA4;ARPP...
# 7   0.000000  AVPR1A;ATXN2;PLSCR1;TMEM97;PNRC1;ATF3;ADH4;GST...
# 8   0.000000  NFX1;NPR2;AGO4;RNMT;POLH;POLA1;UPF3B;RAD52;REV...
# 9   0.000000  FXYD1;ERBB3;COX6A2;DES;CKM;ACTN2;SH3BGR;DAPK2;...
# 10  0.000000  PRKCA;FZD5;MAML2;PSEN2;ARRB1;NOTCH2;TCF7L2;ST3...
# 11  0.000000  TRA2B;IFRD1;HSPD1;HSPE1;SRSF1;HNRNPU;SRPK1;EIF...
# 12  0.000000  PPM1D;SP1;COQ8A;PVT1;WWP1;NHLH2;CCNK;MDM2;SLC1...
# 13  0.000000  MYB;UNC13B;PRKAR2B;MAPT;RET;AFF1;TFPI2;FRK;IL1...
# 14  0.000000  MEP1A;CPN1;C9;TFPI2;GDA;HMGCS2;FGA;HRG;FGG;GP1...
# 15  0.000000  DYRK3;PRKCG;NCK1;ELANE;CD247;IFNG;IL11;IL4;FAS...
# 16  0.000000  DNAJB4;NR4A3;REL;NR4A2;ZBTB10;TIPARP;NFAT5;NFE...
# 17  0.000000  AVPR1A;ERBB3;CREBBP;TNFSF10;DIABLO;BCL2L10;CFL...
# 18  0.000000  APOA4;CBLB;HSPA1A;CASP10;USP8;PLSCR1;ACTN2;C9;...
# 19  0.000000  HHEX;TXNRD1;GCLC;MPO;EGLN2;CAT;MBP;SRXN1;IPCEF...
# 20  0.000000  HUWE1;LRIG1;PLSCR1;TNFSF10;RABGAP1L;MXD1;SH3BG...
# 21  0.000000  PPM1D;TRA2B;HUS1;SRSF1;PAN2;EED;LUC7L3;CCP110;...
# 22  0.000000  VEGFA;VTN;PGLYRP1;LPL;SLCO2A1;PRG2;OLR1;ITGAV;...
# 23  0.000000  DNAJA4;EIF2AK3;HERPUD1;CNOT6;CNOT4;CNOT2;ASNS;...
# 24  0.000000  ACOX1;RIOK3;PPP1R15B;NKIRAS1;MAP4K3;BAZ2A;FZD4...
# 25  0.000000  ACOX1;EHHADH;PEX11A;ESR2;MLYCD;PEX13;SIAH1;BCL...
# 26  0.000000  TRA2B;CCNT1;SS18;YTHDC1;HUS1;SRSF10;ARID4A;ATR...
# 27  0.000000  DCX;ELP4;HNF1A;NEUROG3;G6PC2;IAPP;AKT3;SRP9;PA...
# 28  0.000000  NCK1;MAPK8;VAV3;TBK1;PDK1;IL4;FASLG;FGF17;PLCB...
# 29  0.000000  XCL1;VCAM1;ARID5B;TDRD7;TRIM25;PLSCR1;TNFSF10;...
# 30  0.000000  MYB;MAPT;FCMR;MAST4;RET;AFF1;LRIG1;SLC19A2;FRK...
# 31  0.000000  VCAM1;TNFRSF11B;TFPI2;MATN2;BDNF;VEGFA;FAS;ID2...
# 32  0.000000  RET;CYP1A1;ASNS;HNRNPU;TFRC;DNAJA1;EIF5;DNAJB1...
# 33  0.000000  IL17RB;CNTFR;CD36;CXCL13;FAS;IL9R;ACVR1B;REG1A...
# 34  0.000000  SOS1;MID1;AKAP13;NCK1;KIF1B;ARHGAP29;TLK1;FGD6...
# 35  0.000000  FABP1;CCL25;CYP4F2;ACOX1;ADH1C;GSTA3;CYP1A1;TM...
# 36  0.000000  VIP;TNFSF15;OPRK1;PROK2;MEP1A;FZD5;KIF1B;TNFSF...
# 37  0.000000  TCF7;SKP2;ADAM17;NUMB;AXIN2;PSEN2;PTCH1;DKK1;D...
# 38  0.000000  L1CAM;CNTFR;VEGFA;OPHN1;NF1;PTCH1;NRCAM;DPYSL2...
# 39  0.000000  FABP2;FABP1;ACOX1;HSPH1;ADH1C;EHHADH;CYP1A1;HM...
# 40  0.000000  PIAS1;ARID5B;ZBTB10;ELK4;APPBP2;ALDH1A3;INPP4B...
# 41  0.000000  TJP1;ARID4B;SMAD3;TGFBR1;TRIM33;SKIL;ID2;BMPR2...
# 42  0.000000  GABRA3;DNMBP;BTBD3;MTMR10;PPBP;PTBP2;ADAMDEC1;...
# 43  0.000000  TOM1L1;SNAP23;ATP6V1B1;KIF1B;MON2;COPB2;ATP1A1...
# 44  0.000000  SLC4A1;RHAG;VEZF1;HBD;TFDP2;ALAS2;RIOK3;SLC30A...
# 45  0.007937  NCOA7;TDRD7;TRIM25;PLSCR1;TENT5A;IFI30;EIF2AK2...
# 46  0.032000  ABCG8;SLCO1A2;AGXT;SLC23A1;NEDD4;PEX11A;GNMT;M...
# 47  0.156863  SOX10;YPEL1;COQ8A;NGB;ARPP21;LGALS7;ATP6V1B1;C...
# 48  0.484848  PLCB4;PRKAR2B;NFIB;TJP1;PRKCA;YTHDC1;PTPRM;PRD...
# 49  0.420000  H1-6;COIL;NPY5R;CHRM4;STRBP;LDHC;ART3;SIRT1;NO...

# %%
pre_res13 = gp.prerank (rnk= alranking, gene_sets = 'miRTarBase_2017', min_size = 150) #integrated path!!!
out13 = []

for term in list(pre_res13.results):
    out13.append([term,
               pre_res13.results[term]['fdr'],
               pre_res13.results[term]['es'],
               pre_res13.results[term]['nes'],
               pre_res13.results[term]['pval'],
                pre_res13.results[term]['matched_genes']])

out_df13 = pd.DataFrame(out13, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df13
# Out:
# 2024-07-08 15:53:59,807 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 15:53:59,837 [WARNING] Duplicated values found in preranked stats: 4.27% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                 Term  fdr        es       nes      pval  \
# 0    hsa-miR-6851-5p  0.0 -0.314189 -1.642709  0.000000
# 1    hsa-miR-5589-5p  0.0 -0.334804 -1.710864  0.000000
# 2       hsa-miR-4514  0.0 -0.507563 -2.374106  0.000000
# 3    hsa-miR-6739-5p  0.0 -0.370144 -1.818783  0.000000
# 4       hsa-miR-449a  0.0 -0.375686 -1.732634  0.000000
# ..               ...  ...       ...       ...       ...
# 707      hsa-miR-297  1.0  0.288031  1.100598  0.256111
# 708  hsa-miR-6771-3p  1.0  0.238763  0.928178  0.669102
# 709  mmu-miR-466d-3p  1.0  0.285429  1.083171  0.289362
# 710  hsa-miR-4789-5p  1.0  0.278904  1.086251  0.290758
# 711     hsa-miR-4465  1.0  0.238739  0.909077  0.700846
#
#                                          matched_genes
# 0    CYP2B6;SMYD1;MSI2;OPRK1;SRGAP1;MTMR12;NOS1AP;B...
# 1    SLC28A1;ABCG8;DNAJB4;GK5;ZNF670;GPR155;STX17;M...
# 2    TFDP2;RPP14;MDM2;FRK;AGXT2;WARS2;HOXA10;ZNF490...
# 3    SP1;ZBTB33;WAC;NR2E1;POU3F2;YPEL4;ANGEL1;TET3;...
# 4    HSPA1B;BMP3;DYRK3;HOXA13;NEUROD2;UBXN2B;VAV3;C...
# ..                                                 ...
# 707  ASB11;WDR72;CHORDC1;SV2B;ZBTB34;RGS5;NEUROD2;Z...
# 708  MTRNR2L10;ABCG5;KIAA1958;MTRNR2L6;OTUD3;ACOX1;...
# 709  NEU4;PIAS1;PRKCA;LHFPL3;TMEM241;ZBTB39;TET3;SL...
# 710  SLC28A1;WDR72;SHISA9;SV2B;SOS1;NCOA7;USF3;PIAS...
# 711  PCK1;MTMR12;ZNF664;EP300;TET3;DDX3X;RBM48;MDM2...
#
# [712 rows x 6 columns]

# %%
axs = pre_res8.plot(terms=out_df8.iloc[0:10].Term,
                   #legend_kws={'loc': (1.2, 0)}, # set the legend loc
                   show_ranking=True, # whether to show the second yaxis 
                   figsize=(6,5),
                  legend_kws={'loc':(1.2,0)})
    #mirtarbase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[282], line 1
# ----> 1 axs = pre_res8.plot(terms=out_df8.iloc[0:10].Term,
#       2                    #legend_kws={'loc': (1.2, 0)}, # set the legend loc
#       3                    show_ranking=True, # whether to show the second yaxis
#       4                    figsize=(6,5),
#       5                   legend_kws={'loc':(1.2,0)})
#
# NameError: name 'pre_res8' is not defined

# %% [markdown]
# # PCA all

# %%
sc.pp.neighbors(ffdds,n_pcs=20)

# %%
sc.tl.umap(ffdds)

# %%
sc.pl.umap(ffdds, color= 'condition')
# Out:
# C:\Users\Hasan\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# PCA results indicate that the TMAs and TWAs in 2 clusters sharing similar aspects, with minimal batch effects

# %% [markdown]
# # lncRNA

# %%
for i in range(1, 143):
    tmdf[f'tm{i}'] = tmdf[f'tm{i}'][tmdf[f'tm{i}']["gene_type"] == "lncRNA"]
for i in range(1, 39):
    twdf[f'tw{i}'] = twdf[f'tw{i}'][twdf[f'tw{i}']["gene_type"] == "lncRNA"]
    
twun = pd.DataFrame()
for i in range(1,39):
    new_column = pd.DataFrame(zip(twdf[f'tw{i}']['unstranded']),columns = [f'tw{i}'])
    twun = pd.concat([twun, new_column], axis=1)
    
tmun = pd.DataFrame()
for i in range(1,143):
    new_column = pd.DataFrame(zip(tmdf[f'tm{i}']['unstranded']),columns = [f'tm{i}'])
    tmun = pd.concat([tmun, new_column], axis=1)
    
twcounts = pd.DataFrame(zip(tmdf['tm1']['gene_id']), columns = ['geneid']) # preparing the gene id column
counts = pd.concat([twcounts,tmun,twun], axis= 1) # preparing the counts table for DGE
counts = counts.set_index('geneid')
counts = counts[counts.sum(axis=1)>0]
counts = counts.T
m_list = ['d']* 143
w_list = ['c']* 38
condition_list = m_list + w_list
metadata = pd.DataFrame(zip(counts.index, condition_list), columns = ['sample','condition'])
metadata = metadata.set_index('sample')

# %% [markdown]
# # Differential Expression

# %%
dds = DeseqDataSet(counts = counts,
                  metadata = metadata,
                  design_factors = 'condition')

# %%
dds = DeseqDataSet(counts = counts,
                  metadata = metadata,
                  design_factors = 'condition')
dds.deseq2()
stat_res = DeseqStats (dds, n_cpus = 10, contrast=('condition','d','c'))
stat_res.summary()
res = stat_res.results_df
linco= pd.merge(res, twdf['tw1'][['gene_id','gene_name']], left_on='geneid',right_on='gene_id')
degs = linco[(abs(linco.log2FoldChange) > 0.5)&(linco.padj<0.05)]
# Out:
# Fitting size factors...
# ... done in 0.12 seconds.
#
# Fitting dispersions...
# ... done in 8.03 seconds.
#
# Fitting dispersion trend curve...
# ... done in 7.85 seconds.
#
# Fitting MAP dispersions...
# ... done in 8.21 seconds.
#
# Fitting LFCs...
# ... done in 54.26 seconds.
#
# Refitting 830 outliers.
#
# Fitting dispersions...
# ... done in 0.89 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.89 seconds.
#
# Fitting LFCs...
# ... done in 0.90 seconds.
#
# Running Wald tests...
# ... done in 9.36 seconds.
# Log2 fold change & Wald test p-value: condition d vs c
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# geneid
# ENSG00000082929.8    15.338126        0.234952  0.250731  0.937068  0.348724
# ENSG00000083622.8    80.485163        0.509860  0.408015  1.249610  0.211442
# ENSG00000093100.13   13.509626        0.457503  0.200061  2.286812  0.022207
# ENSG00000099869.8    19.775059        0.053344  0.304691  0.175074  0.861021
# ENSG00000103472.10   19.512350       -0.058337  0.150810 -0.386826  0.698885
# ...                        ...             ...       ...       ...       ...
# ENSG00000288659.1     0.186153       -0.052895  1.425556 -0.037105  0.970401
# ENSG00000288662.1     8.297870        0.312188  0.385211  0.810433  0.417691
# ENSG00000288663.1    22.203233       -0.066275  0.126171 -0.525280  0.599389
# ENSG00000288667.1    16.327110        0.370816  0.430688  0.860983  0.389247
# ENSG00000288670.1   208.043602       -0.159306  0.119164 -1.336867  0.181266
#
#                         padj
# geneid
# ENSG00000082929.8   0.816936
# ENSG00000083622.8   0.808916
# ENSG00000093100.13  0.539566
# ENSG00000099869.8   0.955842
# ENSG00000103472.10  0.895548
# ...                      ...
# ENSG00000288659.1        NaN
# ENSG00000288662.1   0.828300
# ENSG00000288663.1   0.863498
# ENSG00000288667.1   0.822404
# ENSG00000288670.1   0.801500
#
# [16152 rows x 6 columns]

# %% [markdown]
# # GSEA lncRNA

# %%
ranking = linco[['gene_name','stat']].dropna().sort_values('stat',ascending= False)

# %%
ranking
# Out:
#         gene_name      stat
# 2430   AC011287.1  5.663576
# 1043   AC010789.1  5.317822
# 6260        PURPL  5.019843
# 13277  FP236383.3  4.937115
# 2850    LINC01436  4.824735
# ...           ...       ...
# 15245  AL732437.2 -4.881078
# 11202   LINC01711 -4.945275
# 4710    UNC5B-AS1 -5.050205
# 6993   AC091182.2 -5.062578
# 6729    LINC01605 -5.118729
#
# [16152 rows x 2 columns]

# %%
pre_res1 = gp.prerank (rnk= ranking, gene_sets = r" \Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c2.cp.kegg.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path, no results for this set
out1 = []

for term in list(pre_res1.results):
    out1.append([term,
               pre_res1.results[term]['fdr'],
               pre_res1.results[term]['es'],
               pre_res1.results[term]['nes'],
               pre_res1.results[term]['pval'],
                pre_res1.results[term]['matched_genes']])

out_df1 = pd.DataFrame(out1, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df1
# Out:
# 2024-07-08 21:18:09,744 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:18:09,782 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2024-07-08 21:18:09,821 [ERROR] No gene sets passed through filtering condition !!!
# Hint 1: Try to lower min_size or increase max_size !
# Hint 2: Check gene symbols are identifiable to your gmt input.
# Hint 3: Gene symbols curated in Enrichr web services are all upcases.
#
# 2024-07-08 21:18:09,829 [ERROR] The first entry of your gene_sets (gmt) look like this : { KEGG_N_GLYCAN_BIOSYNTHESIS: [ALG13, DOLPP1, RPN1, ALG14, MAN1B1, ALG3, B4GALT1, MGAT5, RPN2, STT3A, MGAT3, DAD1, MGAT2, ALG12, TUSC3, MAN1C1, DPM2, DPM1, GANAB, ALG1, MGAT4A, ALG10B, STT3B, MAN1A2, ALG10, ALG11, ALG8, ALG2, DPAGT1, RFT1, DPM3, DDOST, MGAT4B, ALG6, MAN2A2, MAN1A1, MAN2A1, ST6GAL1, B4GALT3, ALG5, B4GALT2, MGAT5B, ALG9, MOGS, FUT8, MGAT1]}
# 2024-07-08 21:18:09,839 [ERROR] The first 5 genes look like this : [ AC011287.1, AC010789.1, PURPL, FP236383.3, LINC01436 ]
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 pre_res1 = gp.prerank (rnk= ranking, gene_sets = r"C:\Users\Hasan\Desktop\Research\r0MAPK in NSCLC\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c2.cp.kegg.v2023.1.Hs.symbols.gmt", min_size = 3)
#       2 out1 = []
#       4 for term in list(pre_res1.results):
#
# File ~\anaconda3\Lib\site-packages\gseapy\__init__.py:377, in prerank(rnk, gene_sets, outdir, pheno_pos, pheno_neg, min_size, max_size, permutation_num, weighted_score_type, ascending, threads, figsize, format, graph_num, no_plot, seed, verbose, *arg, **kwarg)
#     357     threads = kwarg["processes"]
#     358 pre = Prerank(
#     359     rnk,
#     360     gene_sets,
#    (...)
#     375     verbose,
#     376 )
# --> 377 pre.run()
#     378 return pre
#
# File ~\anaconda3\Lib\site-packages\gseapy\gsea.py:435, in Prerank.run(self)
#     433 self._logger.info("Parsing data files for GSEA.............................")
#     434 # filtering out gene sets and build gene sets dictionary
# --> 435 gmt = self.load_gmt(gene_list=dat2.index.values, gmt=self.gene_sets)
#     436 self.gmt = gmt
#     437 self._logger.info(
#     438     "%04d gene_sets used for further statistical testing....." % len(gmt)
#     439 )
#
# File ~\anaconda3\Lib\site-packages\gseapy\base.py:302, in GSEAbase.load_gmt(self, gene_list, gmt)
#     294     self._logger.error(
#     295         "The first entry of your gene_sets (gmt) look like this : %s"
#     296         % dict_head
#     297     )
#     298     self._logger.error(
#     299         "The first 5 genes look like this : [ %s ]"
#     300         % (", ".join(list(gene_list)[:5]))
#     301     )
# --> 302     raise LookupError(msg)
#     304 # self._gmtdct = genesets_dict
#     305 return genesets_dict
#
# LookupError: No gene sets passed through filtering condition !!!
# Hint 1: Try to lower min_size or increase max_size !
# Hint 2: Check gene symbols are identifiable to your gmt input.
# Hint 3: Gene symbols curated in Enrichr web services are all upcases.

# %%
pre_res2 = gp.prerank (rnk= ranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c3.all.v2023.1.Hs.symbols.gmt", min_size =3) #Replace with path 
out2 = []

for term in list(pre_res2.results):
    out2.append([term,
               pre_res2.results[term]['fdr'],
               pre_res2.results[term]['es'],
               pre_res2.results[term]['nes'],
               pre_res2.results[term]['pval'],
                pre_res2.results[term]['matched_genes']])

out_df2 = pd.DataFrame(out2, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df2
# Out:
# 2024-07-08 21:46:03,309 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:46:03,322 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                     Term       fdr        es       nes      pval  \
# 0    ZNF513_TARGET_GENES  0.011695 -0.555179 -2.189123  0.000000
# 1     DNMT1_TARGET_GENES  0.037520 -0.742609 -1.995606  0.006349
# 2       SMTTTTGT_UNKNOWN  0.042231 -0.818718 -2.011062  0.000000
# 3      FXR1_TARGET_GENES  0.044830 -0.486271 -1.961863  0.000000
# 4    CHAF1A_TARGET_GENES  0.056524 -0.835714 -2.024104  0.000000
# ..                   ...       ...       ...       ...       ...
# 662  ZNF362_TARGET_GENES  1.000000  0.322279  1.035018  0.424516
# 663  NKX2_5_TARGET_GENES  1.000000  0.269007  0.999099  0.473746
# 664   AEBP2_TARGET_GENES  1.000000  0.269040  0.933385  0.598773
# 665    SKIL_TARGET_GENES  1.000000  0.256896  0.987417  0.497136
# 666  ZNF510_TARGET_GENES  1.000000  0.326351  0.572014  0.960380
#
#                                          matched_genes
# 0    HOXB-AS3;MIR124-1HG;LINC00461;RNF217-AS1;SLIT3...
# 1    CENATAC-DT;AFDN-DT;LINC02380;OTUD6B-AS1;PRANCR...
# 2    ZNF436-AS1;KIRREL3-AS3;PRR34;COLCA1;ILF3-DT;MI...
# 3    ALOX12-AS1;MORC2-AS1;BMS1P4;HCG25;PRMT5-AS1;SE...
# 4    CDYL-AS1;ZMIZ1-AS1;IRAIN;LINC01664;SCAMP1-AS1;...
# ..                                                 ...
# 662  HOXA11-AS;BMS1P4;FANK1-AS1;LINC01842;WEE2-AS1;...
# 663  LINC00339;LINC02474;PCAT7;SOX2-OT;TMEM202-AS1;...
# 664  RNFT1-DT;INKA2-AS1;PCAT7;KLF3-AS1;TMEM202-AS1;...
# 665  PURPL;RNFT1-DT;LINC00511;PCAT7;GRHL3-AS1;CXXC4...
# 666            TTC28-AS1;C21orf62-AS1;LRRC8C-DT;SNHG30
#
# [667 rows x 6 columns]

# %%
pre_res3 = gp.prerank (rnk= ranking, gene_sets = r" \Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c3.mir.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out3 = []

for term in list(pre_res3.results):
    out3.append([term,
               pre_res3.results[term]['fdr'],
               pre_res3.results[term]['es'],
               pre_res3.results[term]['nes'],
               pre_res3.results[term]['pval'],
                pre_res3.results[term]['matched_genes']])

out_df3 = pd.DataFrame(out3, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df3
# Out:
# 2024-07-08 21:27:31,772 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:27:31,803 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#          Term       fdr        es       nes      pval  \
# 0      MIR765  0.386842 -0.806415 -1.378840  0.135802
# 1   MIR153_5P  0.477016  0.552258  1.023835  0.470497
# 2   MIR576_5P  0.935526 -0.347643 -0.589831  0.930851
# 3  MIR664A_3P  0.963158 -0.487394 -0.834787  0.647520
#
#                                      matched_genes
# 0                     CCDC28A-AS1;LMO7DN;LINC02873
# 1  DOCK8-AS1;RPP38-DT;CCDC28A-AS1;C15orf32;PELATON
# 2                            LINC01517;RGS5;CCDC39
# 3                             RGS5;LMO7DN;C15orf32

# %%
pre_res4 = gp.prerank (rnk= ranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c3.tft.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out4 = []

for term in list(pre_res4.results):
    out4.append([term,
               pre_res4.results[term]['fdr'],
               pre_res4.results[term]['es'],
               pre_res4.results[term]['nes'],
               pre_res4.results[term]['pval'],
                pre_res4.results[term]['matched_genes']])

out_df4 = pd.DataFrame(out4, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df4
# Out:
# 2024-07-08 21:27:40,518 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:27:40,545 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                     Term       fdr        es       nes      pval  \
# 0    ZNF513_TARGET_GENES  0.011694 -0.555179 -2.189123  0.000000
# 1     DNMT1_TARGET_GENES  0.037517 -0.742609 -1.995606  0.006349
# 2       SMTTTTGT_UNKNOWN  0.042227 -0.818718 -2.011062  0.000000
# 3      FXR1_TARGET_GENES  0.044825 -0.486271 -1.961863  0.000000
# 4    CHAF1A_TARGET_GENES  0.056519 -0.835714 -2.024104  0.000000
# ..                   ...       ...       ...       ...       ...
# 658     TGCGCANK_UNKNOWN  1.000000  0.518094  0.965322  0.539557
# 659   MAML1_TARGET_GENES  1.000000  0.351783  1.071336  0.376159
# 660    MZF1_TARGET_GENES  1.000000  0.292189  1.086975  0.317536
# 661  ZNF708_TARGET_GENES  1.000000  0.656243  1.158471  0.285714
# 662    NME2_TARGET_GENES  1.000000  0.490276  1.095791  0.356707
#
#                                          matched_genes
# 0    HOXB-AS3;MIR124-1HG;LINC00461;RNF217-AS1;SLIT3...
# 1    CENATAC-DT;AFDN-DT;LINC02380;OTUD6B-AS1;PRANCR...
# 2    ZNF436-AS1;KIRREL3-AS3;PRR34;COLCA1;ILF3-DT;MI...
# 3    ALOX12-AS1;MORC2-AS1;BMS1P4;HCG25;PRMT5-AS1;SE...
# 4    CDYL-AS1;ZMIZ1-AS1;IRAIN;LINC01664;SCAMP1-AS1;...
# ..                                                 ...
# 658           RPP38-DT;DLEU2;C14orf178;LINC01106;DLEU1
# 659  LINC00511;EPN2-AS1;LINC01624;LINC02579;MIR155H...
# 660  HOXA11-AS;DLX6-AS1;IQCH-AS1;ADD3-AS1;HOXB-AS3;...
# 661                     LINC00662;JPX;HCCAT5;LINC01596
# 662  ST8SIA6-AS1;LINC00310;SPATA42;LINC02645;LINC00...
#
# [663 rows x 6 columns]

# %%
pre_res6 = gp.prerank (rnk= ranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c5.go.bp.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out6 = []

for term in list(pre_res6.results):
    out6.append([term,
               pre_res6.results[term]['fdr'],
               pre_res6.results[term]['es'],
               pre_res6.results[term]['nes'],
               pre_res6.results[term]['pval'],
                pre_res6.results[term]['matched_genes']])

out_df6 = pd.DataFrame(out6, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df6
# Out:
# 2024-07-08 21:33:29,888 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:33:29,905 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                                  Term       fdr        es  \
# 0         GOBP_NEGATIVE_REGULATION_OF_GENE_EXPRESSION  0.024008  0.588768
# 1         GOBP_POSITIVE_REGULATION_OF_GENE_EXPRESSION  0.072729  0.725684
# 2       GOBP_EPIGENETIC_REGULATION_OF_GENE_EXPRESSION  0.193473  0.827221
# 3                           GOBP_CHROMATIN_REMODELING  0.193473  0.827221
# 4                   GOBP_HETEROCHROMATIN_ORGANIZATION  0.193473  0.827221
# ..                                                ...       ...       ...
# 58                         GOBP_RNA_CATABOLIC_PROCESS  0.896127  0.431891
# 59         GOBP_REGULATION_OF_MIRNA_CATABOLIC_PROCESS  0.896127  0.431891
# 60               GOBP_RESPONSE_TO_ENDOGENOUS_STIMULUS  0.965876  0.351647
# 61  GOBP_POSITIVE_REGULATION_OF_MACROMOLECULE_BIOS...  1.000000 -0.706346
# 62  GOBP_POSITIVE_REGULATION_OF_RNA_METABOLIC_PROCESS  1.000000 -0.537145
#
#          nes      pval                                      matched_genes
# 0   1.758262  0.001370  HOXA11-AS;HOXB-AS3;HOXA10-AS;MIR137HG;TSIX;CDK...
# 1   1.625097  0.016845  HOXB-AS3;CDKN2B-AS1;CRYZL2P-SEC16B;FTX;H19;NEA...
# 2   1.445428  0.035200                      TSIX;CDKN2B-AS1;XIST;KCNQ1OT1
# 3   1.445428  0.035200                      TSIX;CDKN2B-AS1;XIST;KCNQ1OT1
# 4   1.445428  0.035200                      TSIX;CDKN2B-AS1;XIST;KCNQ1OT1
# ..       ...       ...                                                ...
# 58  0.704617  0.884679                                 KCNQ1OT1;MIAT;GAS5
# 59  0.704617  0.884679                                 KCNQ1OT1;MIAT;GAS5
# 60  0.579555  0.953411                            KCNQ1OT1;FBXW7-AS1;GAS5
# 61 -1.224514  0.276215                             NFE4;BACE1-AS;MIR9-1HG
# 62 -1.096974  0.347107                   KCNQ1OT1;NFE4;MIAT;GAS5;MIR9-1HG
#
# [63 rows x 6 columns]

# %%
pre_res7 = gp.prerank (rnk= ranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c5.go.cc.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out7= []

for term in list(pre_res7.results):
    out7.append([term,
               pre_res7.results[term]['fdr'],
               pre_res7.results[term]['es'],
               pre_res7.results[term]['nes'],
               pre_res7.results[term]['pval'],
                pre_res7.results[term]['matched_genes']])

out_df7 = pd.DataFrame(out7, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df7
# Out:
# 2024-07-08 21:34:16,452 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:34:16,484 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                       Term       fdr        es       nes  \
# 0  GOCC_NUCLEAR_PROTEIN_CONTAINING_COMPLEX  0.072896  0.815528  1.465536
# 1           GOCC_RIBONUCLEOPROTEIN_COMPLEX  0.086150  0.540400  1.490408
# 2                      GOCC_SEX_CHROMOSOME  0.097084  0.847426  1.398252
# 3                          GOCC_CHROMOSOME  0.165673  0.847479  1.494808
# 4                           GOCC_NUCLEOLUS  0.217550 -0.452168 -1.231691
# 5               GOCC_RNAI_EFFECTOR_COMPLEX  0.226640  0.494400  1.239904
# 6                        GOCC_NUCLEAR_BODY  0.477800  0.626127  1.009730
#
#        pval                                      matched_genes
# 0  0.033691                           TERC;TSIX;WEE2-AS1;OVAAL
# 1  0.039829  HOXA10-AS;MIR137HG;TERC;LINC00461;WEE2-AS1;SNA...
# 2  0.052215                                    TSIX;FIRRE;XIST
# 3  0.021978                               TERC;TSIX;FIRRE;XIST
# 4  0.178042  ELOVL2-AS1;PCAT18;KCNQ1OT1;SCARNA9;LINC01151;S...
# 5  0.200000  HOXA10-AS;MIR137HG;LINC00461;MEG3;MIR155HG;NEA...
# 6  0.481164                                  TERC;NEAT1;SNHG10

# %%
pre_res8 = gp.prerank (rnk= ranking, gene_sets = "GO_Molecular_Function_2023", min_size = 3) 
out8 = []

for term in list(pre_res8.results):
    out8.append([term,
               pre_res8.results[term]['fdr'],
               pre_res8.results[term]['es'],
               pre_res8.results[term]['nes'],
               pre_res8.results[term]['pval'],
                pre_res8.results[term]['matched_genes']])

out_df8 = pd.DataFrame(out8, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df8
# Out:
# 2024-07-08 21:34:26,047 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:34:26,092 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2024-07-08 21:34:26,187 [ERROR] No gene sets passed through filtering condition !!!
# Hint 1: Try to lower min_size or increase max_size !
# Hint 2: Check gene symbols are identifiable to your gmt input.
# Hint 3: Gene symbols curated in Enrichr web services are all upcases.
#
# 2024-07-08 21:34:26,189 [ERROR] The first entry of your gene_sets (gmt) look like this : { 1-Acylglycerol-3-Phosphate O-acyltransferase Activity (GO:0003841): [LPGAT1, MBOAT7, TAFAZZIN, LPCAT2, MBOAT2, LPCAT1, AGPAT1, AGPAT2, CRLS1, LCLAT1, AGPAT3, AGPAT4, AGPAT5, MBOAT1, LPCAT3, GPAT2, GPAT4, GPAT3, PNPLA3]}
# 2024-07-08 21:34:26,198 [ERROR] The first 5 genes look like this : [ AC011287.1, AC010789.1, PURPL, FP236383.3, LINC01436 ]
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 pre_res8 = gp.prerank (rnk= ranking, gene_sets = "GO_Molecular_Function_2023", min_size = 3)
#       2 out8 = []
#       4 for term in list(pre_res8.results):
#
# File ~\anaconda3\Lib\site-packages\gseapy\__init__.py:377, in prerank(rnk, gene_sets, outdir, pheno_pos, pheno_neg, min_size, max_size, permutation_num, weighted_score_type, ascending, threads, figsize, format, graph_num, no_plot, seed, verbose, *arg, **kwarg)
#     357     threads = kwarg["processes"]
#     358 pre = Prerank(
#     359     rnk,
#     360     gene_sets,
#    (...)
#     375     verbose,
#     376 )
# --> 377 pre.run()
#     378 return pre
#
# File ~\anaconda3\Lib\site-packages\gseapy\gsea.py:435, in Prerank.run(self)
#     433 self._logger.info("Parsing data files for GSEA.............................")
#     434 # filtering out gene sets and build gene sets dictionary
# --> 435 gmt = self.load_gmt(gene_list=dat2.index.values, gmt=self.gene_sets)
#     436 self.gmt = gmt
#     437 self._logger.info(
#     438     "%04d gene_sets used for further statistical testing....." % len(gmt)
#     439 )
#
# File ~\anaconda3\Lib\site-packages\gseapy\base.py:302, in GSEAbase.load_gmt(self, gene_list, gmt)
#     294     self._logger.error(
#     295         "The first entry of your gene_sets (gmt) look like this : %s"
#     296         % dict_head
#     297     )
#     298     self._logger.error(
#     299         "The first 5 genes look like this : [ %s ]"
#     300         % (", ".join(list(gene_list)[:5]))
#     301     )
# --> 302     raise LookupError(msg)
#     304 # self._gmtdct = genesets_dict
#     305 return genesets_dict
#
# LookupError: No gene sets passed through filtering condition !!!
# Hint 1: Try to lower min_size or increase max_size !
# Hint 2: Check gene symbols are identifiable to your gmt input.
# Hint 3: Gene symbols curated in Enrichr web services are all upcases.

# %%
pre_res9 = gp.prerank (rnk= ranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c5.hpo.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out9= []

for term in list(pre_res9.results):
    out9.append([term,
               pre_res9.results[term]['fdr'],
               pre_res9.results[term]['es'],
               pre_res9.results[term]['nes'],
               pre_res9.results[term]['pval'],
                pre_res9.results[term]['matched_genes']])

out_df9 = pd.DataFrame(out9, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df9
# Out:
# 2024-07-08 21:43:16,976 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:43:16,988 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                                                  Term       fdr        es  \
# 0                   HP_ABNORMAL_INFLAMMATORY_RESPONSE  0.209038  0.758055
# 1                      HP_ABNORMAL_RETINAL_MORPHOLOGY  0.209038  0.758055
# 2                        HP_ABNORMALITY_OF_THE_SPLEEN  0.209038  0.758055
# 3                     HP_ABNORMALITY_OF_THE_DENTITION  0.209109  0.766666
# 4                  HP_INTRAUTERINE_GROWTH_RETARDATION  0.214361  0.725279
# ..                                                ...       ...       ...
# 171  HP_ABNORMALITY_OF_REPRODUCTIVE_SYSTEM_PHYSIOLOGY  0.698329 -0.767082
# 172                  HP_ABNORMAL_LONG_BONE_MORPHOLOGY  0.732018  0.846512
# 173         HP_ABNORMAL_CEREBRAL_VENTRICLE_MORPHOLOGY  0.814597  0.469099
# 174                               HP_VENTRICULOMEGALY  0.814597  0.469099
# 175               HP_ABNORMAL_EMOTION_AFFECT_BEHAVIOR  0.895461  0.425104
#
#           nes      pval                    matched_genes
# 0    1.417586  0.068182  TERC;MEG3;RMRP;IL12A-AS1;CCDC39
# 1    1.417586  0.068182  TERC;MEG3;RMRP;IL12A-AS1;CCDC39
# 2    1.417586  0.068182  TERC;MEG3;RMRP;IL12A-AS1;CCDC39
# 3    1.439980  0.044628     TERC;H19;KCNQ1OT1;RMRP;PWRN1
# 4    1.441002  0.057508   TERC;MEG3;H19;HYMAI;RMRP;PWRN1
# ..        ...       ...                              ...
# 171 -1.325367  0.165775             PWRN1;ATXN8OS;CCDC39
# 172  1.588312  0.006431    TERC;GNAS-AS1;MEG3;RMRP;PWRN1
# 173  0.770321  0.819699            KCNQ1OT1;PWRN1;CCDC39
# 174  0.770321  0.819699            KCNQ1OT1;PWRN1;CCDC39
# 175  0.680311  0.901007          MIR17HG;IL12A-AS1;PWRN1
#
# [176 rows x 6 columns]

# %%
pre_res10 = gp.prerank (rnk= ranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\c6.all.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out10 = []

for term in list(pre_res10.results):
    out10.append([term,
               pre_res10.results[term]['fdr'],
               pre_res10.results[term]['es'],
               pre_res10.results[term]['nes'],
               pre_res10.results[term]['pval'],
                pre_res10.results[term]['matched_genes']])

out_df10 = pd.DataFrame(out10, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df10
# Out:
# 2024-07-08 21:44:33,367 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:44:33,384 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                       Term       fdr        es       nes      pval  \
# 0       KRAS.LUNG_UP.V1_UP  0.782218  0.769407  1.241770  0.182724
# 1            STK33_NOMO_DN  0.786870  0.580497  1.205838  0.239329
# 2                NFE2L2.V2  0.830866  0.404975  0.813142  0.708861
# 3         MTOR_UP.N4.V1_DN  0.855645  0.466517  0.826360  0.743178
# 4            STK33_NOMO_UP  0.873219  0.627892  1.122753  0.332273
# 5            JAK2_DN.V1_DN  0.894801  0.506424  1.147442  0.297965
# 6            E2F3_UP.V1_DN  0.899417  0.340984  0.829376  0.704918
# 7             SRC_UP.V1_DN  0.924324  0.398196  0.697369  0.860427
# 8            PDGF_UP.V1_DN  0.928169  0.424580  0.843381  0.711569
# 9             STK33_SKM_DN  0.947683  0.485238  1.042812  0.412371
# 10            DCA_UP.V1_UP  0.959360  0.354765  0.583030  0.970149
# 11     PRC2_SUZ12_UP.V1_DN  0.961337  0.762873  1.244602  0.158155
# 12    KRAS.BREAST_UP.V1_UP  0.964969  0.616356  1.007400  0.479339
# 13            MYC_UP.V1_UP  0.965383 -0.377859 -0.768930  0.738372
# 14       PRC1_BMI_UP.V1_DN  0.982513  0.446476  0.845494  0.706349
# 15      PRC2_EZH2_UP.V1_DN  0.983243 -0.305334 -0.515316  0.987113
# 16            SRC_UP.V1_UP  1.000000 -0.476205 -1.326003  0.135922
# 17         ATF2_S_UP.V1_DN  1.000000  0.535626  0.877853  0.691252
# 18            STK33_SKM_UP  1.000000 -0.397453 -0.676007  0.857923
# 19  BMI1_DN_MEL18_DN.V1_DN  1.000000  0.855169  1.386078  0.056013
# 20       KRAS.600_UP.V1_DN  1.000000 -0.339900 -0.575376  0.947761
# 21           IL21_UP.V1_DN  1.000000 -0.481705 -0.822336  0.679389
# 22           PTEN_DN.V1_DN  1.000000  0.660224  1.050878  0.426370
# 23            MYC_UP.V1_DN  1.000000 -0.351131 -0.771333  0.757660
# 24           CAMP_UP.V1_DN  1.000000 -0.550680 -0.931745  0.530864
# 25            IL2_UP.V1_DN  1.000000  0.704929  1.252074  0.190317
# 26            JNK_DN.V1_DN  1.000000  0.725206  1.268011  0.147011
# 27           IL15_UP.V1_UP  1.000000 -0.512720 -0.895298  0.549020
# 28                STK33_DN  1.000000  0.461373  0.912154  0.603101
# 29           CTIP_DN.V1_DN  1.000000 -0.415896 -0.775582  0.734450
# 30                STK33_UP  1.000000 -0.579692 -1.110408  0.351064
# 31     RAPA_EARLY_UP.V1_UP  1.000000 -0.468496 -0.905439  0.536986
# 32          NOTCH_DN.V1_UP  1.000000  0.578837  0.941259  0.597540
# 33           PTEN_DN.V2_UP  1.000000 -0.568266 -0.976077  0.480100
# 34           SNF5_DN.V1_DN  1.000000  0.533734  0.869052  0.678571
#
#                                         matched_genes
# 0                    LINC00472;MIR124-1HG;N4BP2L2-IT2
# 1   DLX6-AS1;DOCK8-AS1;LINC00926;MROCKI;UCA1;HCG11...
# 2   SOX2-OT;AQP4-AS1;NFE4;MCF2L-AS1;LY86-AS1;LINC0...
# 3                       LINC00342;NEAT1;POLR2J4;HHLA3
# 4                   LINC02003;DPP10-AS1;NEAT1;MIR22HG
# 5   LINC00937;PVT1;NEAT1;C8orf44;HYMAI;POLR2J4;HCG...
# 6   PVT1;LINC00662;GAS8-AS1;SND1-IT1;KCNQ1OT1;WT1-...
# 7                     MIR17HG;WT1-AS;DGCR11;LINC00842
# 8   MIR124-1HG;LINC01558;SMG7-AS1;INE1;ATXN8OS;GAB...
# 9   DPP10-AS1;LINC00926;LINC01913;BFSP2-AS1;LINC02...
# 10                              MIR600HG;HCG9;FAM215A
# 11                       GAS8-AS1;LINC01558;LINC00588
# 12                               FAM30A;RMST;ERC2-IT1
# 13    LINC00628;NFIA-AS1;SLC25A25-AS1;LINC00951;PCOTH
# 14           FAM106A;GAS8-AS1;GUSBP11;LINC02249;PCOTH
# 15                        RHPN1-AS1;ATXN8OS;PDCD4-AS1
# 16  PSG8-AS1;LINC00628;BCRP3;LINC00661;KCNQ1DN;LIN...
# 17                                 NEAT1;MGC4859;RGS5
# 18                         MIR646HG;MIR663AHG;MIR22HG
# 19                           LINC00339;KLF3-AS1;NEAT1
# 20                           KIAA0087;IGF2-AS;FAM215A
# 21                               MIR600HG;DGCR5;PCOTH
# 22                          RFPL1S;LINC-PINT;KIAA0087
# 23  MEG3;LINC00173;LINC00293;RUSC1-AS1;LMNTD2-AS1;...
# 24                           MIR155HG;DGCR5;LINC01089
# 25              LINC00472;LINC01558;LINC00928;AFDN-DT
# 26                     LINC00342;XIST;DSCR4;LINC00588
# 27                               PLAC4;FAM215A;SNHG17
# 28    DOCK8-AS1;LINC00926;MROCKI;CCDC26;UCA1;ZEB1-AS1
# 29               EPB41L4A-DT;GSN-AS1;DGCR11;LINC01963
# 30              MIR646HG;MIR663AHG;MIR22HG;ATP2B1-AS1
# 31                  PART1;ERVK-28;LINC00563;LINC01138
# 32                          LINC01565;GSN-AS1;FAM215A
# 33                              WT1-AS;DGCR11;MIR22HG
# 34                                   XIST;MALAT1;RGS5

# %%
pre_res12 = gp.prerank (rnk= ranking, gene_sets = r"\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\h.all.v2023.1.Hs.symbols.gmt", min_size = 3) #Replace with path 
out12= []

for term in list(pre_res12.results):
    out12.append([term,
               pre_res12.results[term]['fdr'],
               pre_res12.results[term]['es'],
               pre_res12.results[term]['nes'],
               pre_res12.results[term]['pval'],
                pre_res12.results[term]['matched_genes']])

out_df12 = pd.DataFrame(out12, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df12
# Out:
# 2024-07-08 21:44:47,541 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:44:47,554 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2024-07-08 21:44:47,564 [ERROR] No gene sets passed through filtering condition !!!
# Hint 1: Try to lower min_size or increase max_size !
# Hint 2: Check gene symbols are identifiable to your gmt input.
# Hint 3: Gene symbols curated in Enrichr web services are all upcases.
#
# 2024-07-08 21:44:47,567 [ERROR] The first entry of your gene_sets (gmt) look like this : { HALLMARK_TNFA_SIGNALING_VIA_NFKB: [JUNB, CXCL2, ATF3, NFKBIA, TNFAIP3, PTGS2, CXCL1, IER3, CD83, CCL20, CXCL3, MAFF, NFKB2, TNFAIP2, HBEGF, KLF6, BIRC3, PLAUR, ZFP36, ICAM1, JUN, EGR3, IL1B, BCL2A1, PPP1R15A, ZC3H12A, SOD2, NR4A2, IL1A, RELB, TRAF1, BTG2, DUSP1, MAP3K8, ETS2, F3, SDC4, EGR1, IL6, TNF, KDM6B, NFKB1, LIF, PTX3, FOSL1, NR4A1, JAG1, CCL4, GCH1, CCL2, RCAN1, DUSP2, EHD1, IER2, REL, CFLAR, RIPK2, NFKBIE, NR4A3, PHLDA1, IER5, TNFSF9, GEM, GADD45A, CXCL10, PLK2, BHLHE40, EGR2, SOCS3, SLC2A6, PTGER4, DUSP5, SERPINB2, NFIL3, SERPINE1, TRIB1, TIPARP, RELA, BIRC2, CXCL6, LITAF, TNFAIP6, CD44, INHBA, PLAU, MYC, TNFRSF9, SGK1, TNIP1, NAMPT, FOSL2, PNRC1, ID2, CD69, IL7R, EFNA1, PHLDA2, PFKFB3, CCL5, YRDC, IFNGR2, SQSTM1, BTG3, GADD45B, KYNU, G0S2, BTG1, MCL1, VEGFA, MAP2K3, CDKN1A, CCN1, TANK, IFIT2, IL18, TUBB2A, IRF1, FOS, OLR1, RHOB, AREG, NINJ1, ZBTB10, PLPP3, KLF4, CXCL11, SAT1, CSF1, GPR183, PMEPA1, PTPRE, TLR2, ACKR3, KLF10, MARCKS, LAMB3, CEBPB, TRIP10, F2RL1, KLF9, LDLR, TGIF1, RNF19B, DRAM1, B4GALT1, DNAJB4, CSF2, PDE4B, SNN, PLEK, STAT5A, DENND5A, CCND1, RIGI, SPHK1, CD80, TNFAIP8, CCNL1, FUT4, CCRL2, SPSB1, TSC22D1, B4GALT5, SIK1, CLCF1, NFE2L2, FOSB, PER1, NFAT5, ATP2B1, IL12B, IL6ST, SLC16A6, ABCA1, HES1, BCL6, IRS2, SLC2A3, CEBPD, IL23A, SMAD3, TAP1, MSC, IFIH1, IL15RA, TNIP2, BCL3, PANX1, FJX1, EDN1, EIF1, BMP2, DUSP4, PDLIM5, ICOSLG, GFPT2, KLF2, TNC, SERPINB8, MXD1]}
# 2024-07-08 21:44:47,570 [ERROR] The first 5 genes look like this : [ AC011287.1, AC010789.1, PURPL, FP236383.3, LINC01436 ]
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 pre_res12 = gp.prerank (rnk= ranking, gene_sets = r"C:\Users\Hasan\Desktop\Research\r0MAPK in NSCLC\Gene Sets\msigdb_v2023.1.Hs_GMTs\MSigDB\h.all.v2023.1.Hs.symbols.gmt", min_size = 3)
#       2 out12= []
#       4 for term in list(pre_res12.results):
#
# File ~\anaconda3\Lib\site-packages\gseapy\__init__.py:377, in prerank(rnk, gene_sets, outdir, pheno_pos, pheno_neg, min_size, max_size, permutation_num, weighted_score_type, ascending, threads, figsize, format, graph_num, no_plot, seed, verbose, *arg, **kwarg)
#     357     threads = kwarg["processes"]
#     358 pre = Prerank(
#     359     rnk,
#     360     gene_sets,
#    (...)
#     375     verbose,
#     376 )
# --> 377 pre.run()
#     378 return pre
#
# File ~\anaconda3\Lib\site-packages\gseapy\gsea.py:435, in Prerank.run(self)
#     433 self._logger.info("Parsing data files for GSEA.............................")
#     434 # filtering out gene sets and build gene sets dictionary
# --> 435 gmt = self.load_gmt(gene_list=dat2.index.values, gmt=self.gene_sets)
#     436 self.gmt = gmt
#     437 self._logger.info(
#     438     "%04d gene_sets used for further statistical testing....." % len(gmt)
#     439 )
#
# File ~\anaconda3\Lib\site-packages\gseapy\base.py:302, in GSEAbase.load_gmt(self, gene_list, gmt)
#     294     self._logger.error(
#     295         "The first entry of your gene_sets (gmt) look like this : %s"
#     296         % dict_head
#     297     )
#     298     self._logger.error(
#     299         "The first 5 genes look like this : [ %s ]"
#     300         % (", ".join(list(gene_list)[:5]))
#     301     )
# --> 302     raise LookupError(msg)
#     304 # self._gmtdct = genesets_dict
#     305 return genesets_dict
#
# LookupError: No gene sets passed through filtering condition !!!
# Hint 1: Try to lower min_size or increase max_size !
# Hint 2: Check gene symbols are identifiable to your gmt input.
# Hint 3: Gene symbols curated in Enrichr web services are all upcases.

# %%
pre_res13 = gp.prerank (rnk= ranking, gene_sets = 'miRTarBase_2017', min_size = 3) 
out13 = []

for term in list(pre_res13.results):
    out13.append([term,
               pre_res13.results[term]['fdr'],
               pre_res13.results[term]['es'],
               pre_res13.results[term]['nes'],
               pre_res13.results[term]['pval'],
                pre_res13.results[term]['matched_genes']])

out_df13 = pd.DataFrame(out13, columns = ['Term','fdr', 'es', 'nes','pval','matched_genes']).sort_values('fdr').reset_index(drop = True)
out_df13
# Out:
# 2024-07-08 21:44:56,926 [WARNING] Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
# 2024-07-08 21:44:56,937 [WARNING] Duplicated values found in preranked stats: 2.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#                 Term       fdr        es       nes      pval  \
# 0    hsa-miR-6799-5p  0.687733  0.605800  1.002373  0.490260
# 1   hsa-miR-3689a-3p  0.687733  0.605800  1.002373  0.490260
# 2   hsa-miR-3689b-3p  0.687733  0.605800  1.002373  0.490260
# 3     hsa-miR-30b-3p  0.687733  0.605800  1.002373  0.490260
# 4   hsa-miR-1273h-5p  0.687733  0.605800  1.002373  0.490260
# ..               ...       ...       ...       ...       ...
# 61   hsa-miR-6499-3p  1.000000 -0.459450 -0.870245  0.601583
# 62    hsa-miR-124-3p  1.000000  0.719925  1.269790  0.158756
# 63    hsa-miR-873-3p  1.000000  0.740429  1.310582  0.122222
# 64      hsa-miR-4279  1.000000 -0.355117 -0.615485  0.929293
# 65   hsa-miR-4793-3p  1.000000  0.810236  1.324554  0.097087
#
#                              matched_genes
# 0               SLFN12L;LINC00598;DNAH10OS
# 1               SLFN12L;LINC00598;DNAH10OS
# 2               SLFN12L;LINC00598;DNAH10OS
# 3               SLFN12L;LINC00598;DNAH10OS
# 4               SLFN12L;LINC00598;DNAH10OS
# ..                                     ...
# 61            SLFN12L;ELFN2;COLCA1;ARIH2OS
# 62               HOTAIR;NEAT1;DLEU1;CCDC39
# 63  TSPEAR-AS2;SLFN12L;LINC01556;HTR5A-AS1
# 64              TMEM78;LINC00598;LINC01560
# 65            TSPEAR-AS2;SLFN12L;HTR5A-AS1
#
# [66 rows x 6 columns]

# %%
axs = pre_res13.plot(terms=out_df13.iloc[0:5].Term,
                   #legend_kws={'loc': (1.2, 0)}, # set the legend loc
                   show_ranking=True, # whether to show the second yaxis 
                   figsize=(4,5),
                  legend_kws={'loc':(1.2,0)})
    #c3.all.v2023.1.Hs.symbols.gmt

# %% [markdown]
# # SOME FIGURES

# %%
volcano(linco, symbol = 'gene_name', pval_thresh =0.05, log2fc_thresh = 0.5, colors= ['blue','dimgrey','red'])

# %%
volcano(ffres, symbol = 'gene_name', pval_thresh =0.05, log2fc_thresh = 0.5, colors= ['blue','dimgrey','red'])

# %%
dds.layers['log1p']= np.log1p(dds.layers['normed_counts'])

# %%
ndegs=degs.set_index('gene_id')

# %%
ddsigs= dds[:,ndegs.index]
cluster = pd.DataFrame(ddsigs.layers['log1p'].T,
index=ddsigs.var_names,
columns=ddsigs.obs_names)

# %%
ddsigs
# Out:
# AnnData object with n_obs × n_vars = 180 × 38
#     obs: 'condition'
#     uns: 'trend_coeffs', '_squared_logres', 'prior_disp_var', 'pca', 'condition_colors', 'neighbors', 'umap'
#     obsm: 'design_matrix', 'size_factors', 'replaceable', 'X_pca', 'X_umap'
#     varm: 'non_zero', '_rough_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'PCs'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks', 'log1p'
#     obsp: 'distances', 'connectivities'

# %%
sns.clustermap(cluster, z_score=0, cmap="seismic",figsize=(10,8))

# %%
heat= cluster.T
correlation = heat.corr()
# Create a new dataframe with the gene names as the index and columns
heatmap_df = pd.DataFrame(correlation, index=cluster.index, columns=cluster.index)

# %%
sns.clustermap(correlation,figsize=(10,9),cmap= 'seismic')

# %% [markdown]
# # PCA lncRNA

# %% [markdown]
# # TPM for scanpy

# %%
tpwun = pd.DataFrame()
for i in range(1,39):
    new_column = pd.DataFrame(zip(twdf[f'tw{i}']['tpm_unstranded']),columns = [f'tw{i}'])
    tpwun = pd.concat([tpwun, new_column], axis=1)

# %%
tpmun = pd.DataFrame()
for i in range(1,143):
    new_column = pd.DataFrame(zip(tmdf[f'tm{i}']['tpm_unstranded']),columns = [f'tm{i}'])
    tpmun = pd.concat([tpmun, new_column], axis=1)

# %%
tcounts = pd.DataFrame(zip(tmdf['tm1']['gene_id']), columns = ['geneid']) # preparing the gene id column

# %%
tpcounts = pd.concat([tcounts,tpmun,tpwun], axis= 1) # preparing the counts table for DGE no controlsssss

# %%
tpcounts= tpcounts.set_index('geneid')

# %%
tpcounts = tpcounts.T

# %%
intpc=tpcounts.astype(int)

# %%
X.T.index
# Out:
# Index(['C10orf55', 'TNS1-AS1', 'AL117329.1', 'AC010789.1', 'LINC02672',
#        'LINC01537', 'LINC01940', 'AL023755.1', 'AC107419.1', 'AC011287.1',
#        'LINC01436', 'AC005064.1', 'CNTFR-AS1', 'UNC5B-AS1', 'HOXA11-AS',
#        'AC112206.2', 'LINC01234', 'PURPL', 'AC010343.3', 'LINC01605',
#        'AC091182.2', 'LINC02055', 'AP003555.1', 'LINC02688', 'AP000880.1',
#        'TBX5-AS1', 'RHOXF1-AS1', 'LINC00930', 'LINC01269', 'LINC02820',
#        'LINC01711', 'AC087623.2', 'AC010913.1', 'AC009159.3', 'FP236383.3',
#        'AC018865.2', 'AC092979.2', 'AL732437.2'],
#       dtype='object')

# %%
tpm4ml = pd.merge(tpcounts, tmdf['tm1'][['gene_id','gene_name']], left_on= tpcounts.index, right_on=tmdf['tm1']['gene_id'], how= 'right')

# %%
bsdf = X.T

# %%
tpmcountdf = pd.merge(tpm4ml,bsdf, left_on=tpm4ml['gene_name'], right_on= bsdf.index, how= 'right' )

# %%
tpm4ml= tpm4ml.drop(columns='key_0')

# %%
tpm4ml= tpm4ml.set_index('gene_name')

# %%
tpm4ml= tpm4ml[tpm4ml.index.isin(bsdf.index)]

# %%
tpm4ml= tpm4ml.drop(columns='gene_id')

# %%
tpm4ml= tpm4ml.drop(columns='condition')

# %%
tpm4ml=tpm4ml.T

# %%
fitpmdf= pd.merge(tpm4ml, metadata2[['sample','condition']], left_on=tpm4ml.index, right_on=metadata2['sample'], how='right')

# %%
fitpmdf = fitpmdf.drop(columns=['key_0','sample'])

# %%
fitpmdf.to_csv('tpmallml.csv',sep=',')

# %%
tpm4ml['condition']= metadata2['condition']

# %%
tpdds = DeseqDataSet(counts = intpc,
                  metadata = metadata,
                  design_factors = 'condition')

# %%
sc.tl.pca(tpdds)

# %%
sc.pl.pca(tpdds, color = 'condition', size = 500)
# Out:
# C:\Users\Hasan\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pp.neighbors(tpdds,n_pcs=20)

# %%
sc.tl.umap(tpdds)

# %%
sc.pl.umap(tpdds, color= 'condition')
# Out:
# C:\Users\Hasan\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # SCALED ML

# %%
transformedx = np.log1p(X)

# %%
transformedx
# Out:
#      C10orf55  TNS1-AS1  AL117329.1  AC010789.1  LINC02672  LINC01537  \
# 0    4.219508  3.218876    2.079442    0.693147   2.397895   2.944439
# 1    3.135494  3.850148    2.079442    0.000000   0.000000   1.386294
# 2    3.218876  4.406719    2.302585    0.000000   0.000000   2.079442
# 3    3.496508  3.218876    3.526361    0.693147   1.609438   1.945910
# 4    3.178054  4.189655    0.693147    0.000000   0.000000   1.609438
# ..        ...       ...         ...         ...        ...        ...
# 175  4.204693  1.791759    0.000000    0.000000   0.693147   3.044522
# 176  3.367296  1.791759    0.693147    0.000000   0.693147   2.079442
# 177  3.258097  2.944439    1.791759    1.386294   0.000000   2.079442
# 178  2.995732  2.484907    1.609438    0.693147   2.079442   0.693147
# 179  5.087596  2.302585    0.000000    0.000000   2.079442   2.302585
#
#      LINC01940  AL023755.1  AC107419.1  AC011287.1  ...  LINC01269  LINC02820  \
# 0     3.871201    2.833213    1.098612    3.688879  ...   2.397895   0.693147
# 1     1.791759    2.484907    2.302585    3.044522  ...   1.791759   0.693147
# 2     2.833213    2.484907    3.496508    3.044522  ...   3.737670   1.098612
# 3     1.945910    3.091042    2.890372    3.258097  ...   2.708050   0.693147
# 4     4.094345    1.098612    1.609438    0.693147  ...   2.944439   0.000000
# ..         ...         ...         ...         ...  ...        ...        ...
# 175   2.564949    0.693147    1.098612    1.386294  ...   3.401197   0.000000
# 176   0.000000    1.098612    0.000000    1.386294  ...   3.583519   0.000000
# 177   4.077537    2.772589    1.386294    2.890372  ...   3.091042   0.693147
# 178   1.098612    2.079442    1.386294    2.197225  ...   1.791759   0.000000
# 179   1.098612    0.000000    0.000000    1.386294  ...   1.791759   0.000000
#
#      LINC01711  AC087623.2  AC010913.1  AC009159.3  FP236383.3  AC018865.2  \
# 0     4.110874    3.044522    1.791759    3.433987    0.693147    0.000000
# 1     3.988984    3.526361    1.945910    2.944439    0.693147    1.098612
# 2     4.700480    2.833213    2.079442    2.890372    0.000000    0.000000
# 3     4.189655    3.806662    2.484907    3.091042    0.000000    2.079442
# 4     3.988984    2.890372    0.693147    2.708050    0.000000    0.000000
# ..         ...         ...         ...         ...         ...         ...
# 175   4.905275    2.772589    0.693147    2.639057    0.000000    0.000000
# 176   3.433987    3.044522    2.484907    3.465736    0.000000    0.000000
# 177   3.988984    3.135494    2.772589    3.218876    0.693147    1.609438
# 178   2.995732    4.262680    1.609438    2.708050    1.609438    0.000000
# 179   3.988984    4.204693    3.688879    5.117994    0.693147    0.000000
#
#      AC092979.2  AL732437.2
# 0      1.791759    2.639057
# 1      2.995732    2.079442
# 2      2.708050    1.098612
# 3      2.484907    1.098612
# 4      0.000000    1.098612
# ..          ...         ...
# 175    0.000000    0.693147
# 176    0.000000    0.000000
# 177    1.386294    1.945910
# 178    1.386294    0.000000
# 179    0.000000    2.397895
#
# [180 rows x 38 columns]

# %%
# Normalize the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(transformedx)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=69)

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# # Data cleaning for ML
# Here we first take raw counts data. Then, we merge the gene_id column from degs dataframe (differentially expressed genes) with the counts data to get a dataframe containing only the differentially expressed. Afterwards, we drop differential expression data, add the conditions from the metadata (which we used for differential expression above).
#
# Finally, we prepare X_train, y_train, and tests for the ML models.
# This is not needed to try as all preprocessed data was saved separately to immediately implement in the machine learning models.

# %%
mlcounts= counts.T
sigmlcounts = pd.merge(mlcounts, degs,left_on='geneid', right_on='gene_id', how='right')
fmlcounts =sigmlcounts.drop(columns=['baseMean','log2FoldChange','lfcSE','stat','pvalue','padj','gene_id'])
fmlcounts= fmlcounts.set_index('gene_name')
fcounts= fmlcounts.T
m_list = ['1']* 142
w_list = ['0'] * 38
condition_list = m_list + w_list
metadata2 = pd.DataFrame(zip(fcounts.index, condition_list), columns = ['sample','condition'])
ficounts= pd.merge(fcounts,metadata2['condition'], left_on=fcounts.index,right_on=metadata.index,how='right')
ficounts= ficounts.drop(columns='key_0')
X = ficounts.iloc[:,:-1]
y = ficounts['condition'].astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=69)
smote=SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
